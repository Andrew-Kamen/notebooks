# %% [markdown]
# # Heat Map of Trade off between controls and robustness
#
# This notebook presents a heat map illustrating how robustness is constrained by a and dda, as well as highlighting that analytically there are two points of note: bang bang solution, and a minimunm curvature while still accomplishgin a gate solution, which yields

# %% [markdown]
# ## Imports

# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate();
using PiccoloQuantumObjects
using QuantumCollocation
using ForwardDiff
using LinearAlgebra
using Plots
using SparseArrays
using NamedTrajectories
using Statistics
using CairoMakie
using Random
using ColorSchemes
using Makie
using Printf
# Out:
#   Activating project at `~/Documents/research/pulses/project/notebooks/src`
# ┌ Warning: Circular dependency detected.
# │ Precompilation will be skipped for dependencies in this cycle:
# │  ┌ Piccolissimo
# │  └─ QuantumCollocation
# └ @ Base.Precompilation precompilation.jl:651

# %%
# Problem parameters
T = 20
Δt = 0.2
U_goal = GATES.H
H_drive = [PAULIS.X, PAULIS.Y, PAULIS.Z]
piccolo_opts = PiccoloOptions(verbose=false)
pretty_print(X::AbstractMatrix) = Base.show(stdout, "text/plain", X);
sys = QuantumSystem(H_drive)
# Adjoint
∂ₑHₐ = [PAULIS.X, PAULIS.Y, PAULIS.Z]
varsys = VariationalQuantumSystem(
    H_drive,
    ∂ₑHₐ
)
# Out:
# VariationalQuantumSystem: levels = 2, n_drives = 3

# %% [markdown]
# Setup metrics

# %%
function SpaceCurve(traj::NamedTrajectory, U_goal::AbstractMatrix{<:Number}, H_err::AbstractMatrix{<:Number})
    T = traj.T
    first_order_terms = Vector{Matrix{ComplexF64}}(undef, T)
    first_order_integral = zeros(ComplexF64, size(U_goal))

    for i in 1:T
        U = iso_vec_to_operator(traj.Ũ⃗[:, i])
        first_order_integral += U' * H_err * U
        first_order_terms[i] = first_order_integral
    end
    d = size(U_goal)[1]
    space_curve = [[real(tr(PAULIS.X * first_order_terms[t] / (d * T))),
                    real(tr(PAULIS.Y * first_order_terms[t] / (d * T))),
                    real(tr(PAULIS.Z * first_order_terms[t] / (d * T)))] for t in 1:T] 
    return space_curve
end

function space_curve_robustness(traj::NamedTrajectory, U_goal::AbstractMatrix, H_err::AbstractMatrix)
    curve = SpaceCurve(traj, U_goal, H_err)
    # Use the norm of the final point as a robustness measure
    # (larger values indicate more accumulated error sensitivity)
    final_point = curve[end]
    return norm(final_point)
end

function width_robustness(system::AbstractQuantumSystem, traj::NamedTrajectory; thresh::Float64=0.999)
    F = 1.0
    drift = system.H.H_drift
    drive = system.H.H_drives
    pauls = [PAULIS.X, PAULIS.Y, PAULIS.Z]
    widths = []
    for i in 1:3
        ε = 0.0
        err = pauls[i]
        F = 1.0
        while (ε < 0.5 && F >= thresh)
            noisy_drift = drift + ε * err
            noisy_sys = QuantumSystem(noisy_drift, drive)
            F = unitary_rollout_fidelity(traj, noisy_sys)
            ε += 0.0001
        end
        push!(widths, ε)
    end
    return widths
end
# Out:
# width_robustness (generic function with 1 method)

# %%
# Define parameter ranges (logarithmic scale)
a_bounds = 10 .^ range(-1, 1, length=12)  # 1e-1 to 1e1
dda_bounds = 10 .^ range(-1, 1, length=12)  # 1e-1 to 1e1

n_seeds = 2  # Number of random seeds to test

println("Parameter ranges:")
println("a_bounds: ", a_bounds)
println("dda_bounds: ", dda_bounds)
println("Number of seeds: ", n_seeds)

# Initialize results storage - now with an extra dimension for seeds
trajectories = Array{Any}(undef, length(a_bounds), length(dda_bounds), n_seeds)
fidelities = zeros(length(a_bounds), length(dda_bounds), n_seeds)
convergence_times = zeros(length(a_bounds), length(dda_bounds), n_seeds)
final_costs = zeros(length(a_bounds), length(dda_bounds), n_seeds)

# Define error Hamiltonian function
H_ϵ_add = a -> [PAULIS.X, PAULIS.Y, PAULIS.Z]

# Define seeds to use consistently across all parameter combinations
seed_values = [42, 123]  # Same seeds as adjoint notebook for fair comparison

# Parameter sweep
println("\nStarting parameter sweep with multiple seeds...")
for (i, a_bound) in enumerate(a_bounds)
    for (j, dda_bound) in enumerate(dda_bounds)
        println("\n" * "="^60)
        println("Parameter set: a_bound=$(Printf.@sprintf("%.3e", a_bound)), dda_bound=$(Printf.@sprintf("%.3e", dda_bound))")
        println("="^60)
        
        for (seed_idx, seed) in enumerate(seed_values)
            println("\n  Seed $seed_idx (value=$seed):")
            
            # Set random seed for reproducibility
            Random.seed!(seed)
            
            # Create toggle-frame robust problem with current parameters
            tog_prob_test = UnitarySmoothPulseProblem(
                sys, U_goal, T, Δt;
                a_bound = a_bound,
                dda_bound = dda_bound,
                piccolo_options=piccolo_opts,
                activate_rob_loss=true,
                H_err=H_ϵ_add,
            )
            
            # Solve with timing
            elapsed_time = @elapsed begin
                solve!(tog_prob_test, max_iter=500, print_level=0, 
                        options=IpoptOptions(eval_hessian=false))
                solve!(tog_prob_test, max_iter=25, print_level=0)
            end
            
            # Calculate final fidelity
            fidelity = unitary_rollout_fidelity(tog_prob_test.trajectory, sys)
            
            # Store results
            trajectories[i, j, seed_idx] = tog_prob_test.trajectory
            fidelities[i, j, seed_idx] = fidelity
            convergence_times[i, j, seed_idx] = elapsed_time
            Z_vec = vec(tog_prob_test.trajectory)
            final_costs[i, j, seed_idx] = tog_prob_test.objective.L(Z_vec)
            
            println("    -> Fidelity: $(Printf.@sprintf("%.6f", fidelity)), Time: $(Printf.@sprintf("%.2f", elapsed_time))s, Cost: $(Printf.@sprintf("%.4e", final_costs[i, j, seed_idx]))")
        end
        
        # Compare seeds for this parameter combination
        fid_diff = abs(fidelities[i, j, 1] - fidelities[i, j, 2])
        println("\n  Seed comparison:")
        println("    Fidelity difference: $(Printf.@sprintf("%.6f", fid_diff))")
        println("    Best seed: $(fidelities[i, j, 1] >= fidelities[i, j, 2] ? "Seed 1" : "Seed 2")")
    end
end

# Compute statistics across seeds
mean_fidelities = mean(fidelities, dims=3)[:, :, 1]
std_fidelities = std(fidelities, dims=3)[:, :, 1]
max_fidelities = maximum(fidelities, dims=3)[:, :, 1]
min_fidelities = minimum(fidelities, dims=3)[:, :, 1]

mean_times = mean(convergence_times, dims=3)[:, :, 1]
mean_costs = mean(final_costs, dims=3)[:, :, 1]

println("\n" * "="^80)
println("MULTI-SEED ANALYSIS COMPLETE (TOGGLE FRAME)")
println("="^80)
println("\nFidelity statistics across seeds:")
println("  Mean of means: $(Printf.@sprintf("%.6f", mean(mean_fidelities)))")
println("  Mean of stds: $(Printf.@sprintf("%.6f", mean(std_fidelities)))")
println("  Max std: $(Printf.@sprintf("%.6f", maximum(std_fidelities)))")
println("  Overall best: $(Printf.@sprintf("%.6f", maximum(fidelities)))")
println("  Overall worst: $(Printf.@sprintf("%.6f", minimum(fidelities)))")
# Out:
# Parameter ranges:
# a_bounds: [0.1, 0.15199110829529336, 0.23101297000831597, 0.35111917342151316, 0.533669923120631, 0.8111308307896871, 1.2328467394420661, 1.8738174228603839, 2.8480358684358014, 4.328761281083058, 6.579332246575681, 10.0]
# dda_bounds: [0.1, 0.15199110829529336, 0.23101297000831597, 0.35111917342151316, 0.533669923120631, 0.8111308307896871, 1.2328467394420661, 1.8738174228603839, 2.8480358684358014, 4.328761281083058, 6.579332246575681, 10.0]
# Number of seeds: 2
#
# Starting parameter sweep with multiple seeds...
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.000e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.651181, Time: 151.84s, Cost: 4.1365e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.651179, Time: 114.05s, Cost: 4.1365e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000002
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.520e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.671137, Time: 109.86s, Cost: 3.9338e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.671190, Time: 112.46s, Cost: 3.9333e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000054
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=2.310e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.692051, Time: 113.18s, Cost: 3.7215e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.692105, Time: 117.55s, Cost: 3.7209e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000054
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=3.511e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.702041, Time: 129.62s, Cost: 3.6204e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.702095, Time: 129.96s, Cost: 3.6199e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000054
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=5.337e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.717095, Time: 131.00s, Cost: 3.4681e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.717052, Time: 132.12s, Cost: 3.4685e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000043
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=8.111e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 130.13s, Cost: 3.3936e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 127.50s, Cost: 3.3936e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.233e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 130.15s, Cost: 3.3936e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 132.92s, Cost: 3.3936e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.874e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 131.13s, Cost: 3.3936e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 139.05s, Cost: 3.3936e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=2.848e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 133.99s, Cost: 3.3936e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 130.56s, Cost: 3.3936e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=4.329e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 132.08s, Cost: 3.3936e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 119.60s, Cost: 3.3936e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=6.579e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724511, Time: 61.43s, Cost: 3.3930e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 71.19s, Cost: 3.3936e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000054
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.000e+01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724468, Time: 65.18s, Cost: 3.3934e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724457, Time: 63.57s, Cost: 3.3936e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000011
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.000e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.964073, Time: 63.65s, Cost: 8.4867e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.964073, Time: 63.42s, Cost: 8.4867e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.520e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.979536, Time: 63.05s, Cost: 6.8629e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.979496, Time: 63.21s, Cost: 6.8673e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000040
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=2.310e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.987581, Time: 63.79s, Cost: 6.0152e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.987571, Time: 62.92s, Cost: 6.0163e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000010
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=3.511e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.993979, Time: 63.55s, Cost: 5.3327e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.993979, Time: 63.17s, Cost: 5.3327e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=5.337e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.996257, Time: 72.80s, Cost: 5.0893e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.996257, Time: 130.22s, Cost: 5.0893e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=8.111e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.998683, Time: 130.32s, Cost: 4.8239e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.998683, Time: 125.81s, Cost: 4.8239e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000001
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.233e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.995278, Time: 120.95s, Cost: 4.8823e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999306, Time: 122.12s, Cost: 4.7532e+00
#
#   Seed comparison:
#     Fidelity difference: 0.004028
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.874e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999311, Time: 100.43s, Cost: 4.7361e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999179, Time: 59.24s, Cost: 4.7719e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000132
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=2.848e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999048, Time: 61.88s, Cost: 4.7221e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999403, Time: 61.63s, Cost: 4.7370e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000355
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=4.329e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.998626, Time: 62.14s, Cost: 4.8560e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999094, Time: 61.95s, Cost: 4.6931e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000468
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=6.579e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999076, Time: 61.93s, Cost: 4.7902e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999222, Time: 63.15s, Cost: 4.7456e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000147
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.000e+01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
# ...
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.992166, Time: 48.08s, Cost: 3.3045e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999756, Time: 48.33s, Cost: 9.1909e-01
#
#   Seed comparison:
#     Fidelity difference: 0.007590
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=8.111e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999789, Time: 48.00s, Cost: 1.4336e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 48.90s, Cost: 4.5072e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000211
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=1.233e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 49.20s, Cost: 1.3015e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 48.24s, Cost: 7.3748e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=1.874e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 48.91s, Cost: 1.8871e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999998, Time: 48.75s, Cost: 5.1745e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000002
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=2.848e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999999, Time: 48.92s, Cost: 4.4810e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 49.07s, Cost: 3.9897e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=4.329e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999837, Time: 49.04s, Cost: 3.8382e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999999, Time: 48.92s, Cost: 4.0890e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000163
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=6.579e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999998, Time: 49.04s, Cost: 6.8122e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 49.21s, Cost: 1.3494e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000002
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=1.000e+01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 48.53s, Cost: 4.5297e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999999, Time: 48.75s, Cost: 1.7441e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000001
#     Best seed: Seed 1
#
# ================================================================================
# MULTI-SEED ANALYSIS COMPLETE (TOGGLE FRAME)
# ================================================================================
#
# Fidelity statistics across seeds:
#   Mean of means: 0.974897
#   Mean of stds: 0.000300
#   Max std: 0.015421
#   Overall best: 1.000000
#   Overall worst: 0.651179

# %%
# Create comprehensive visualization with multi-seed analysis for Toggle Frame
f = Figure(size=(1800, 1200))

# 1. Mean Fidelity 3D Surface Plot
ax3d = Axis3(f[1, 1:2],
    title="Mean Fidelity Across Seeds vs a_bound and dda_bound (Toggle Frame)",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)",
    zlabel="Mean Fidelity",
    aspect=(1, 1, 0.5)
)

# Create meshgrid for 3D plot
x_3d = repeat(log10.(a_bounds), 1, length(dda_bounds))
y_3d = repeat(log10.(dda_bounds)', length(a_bounds), 1)
z_3d = mean_fidelities

# Create 3D surface
Makie.surface!(ax3d, x_3d, y_3d, z_3d, colormap=:viridis, alpha=0.8)
Makie.contour3d!(ax3d, x_3d, y_3d, z_3d, levels=10, linewidth=1, alpha=0.6)

# 2. Mean Fidelity 2D Heatmap
ax_heat_mean = Axis(f[2, 1],
    title="Mean Fidelity Heatmap",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)

hm_mean = Makie.heatmap!(ax_heat_mean, log10.(a_bounds), log10.(dda_bounds), mean_fidelities,
             colormap=:viridis, colorrange=(0.95, 1.0))
Colorbar(f[2, 2], hm_mean, label="Mean Fidelity")

Makie.contour!(ax_heat_mean, log10.(a_bounds), log10.(dda_bounds), mean_fidelities,
        levels=[0.99, 0.995, 0.999], color=:white, linewidth=1.5)

# 3. Standard Deviation Heatmap (shows seed variability)
ax_heat_std = Axis(f[1, 3],
    title="Fidelity Std Dev Across Seeds",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)

hm_std = Makie.heatmap!(ax_heat_std, log10.(a_bounds), log10.(dda_bounds), std_fidelities,
             colormap=:reds)
Colorbar(f[1, 4], hm_std, label="Std Dev")

# 4. Max-Min Difference (shows range across seeds)
fidelity_range = max_fidelities - min_fidelities
ax_heat_range = Axis(f[2, 3],
    title="Fidelity Range Across Seeds",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)

hm_range = Makie.heatmap!(ax_heat_range, log10.(a_bounds), log10.(dda_bounds), fidelity_range,
             colormap=:plasma)
Colorbar(f[2, 4], hm_range, label="Max - Min")

# 5. Cross-section comparison showing variability
ax_cross1 = Axis(f[3, 1:2],
    title="Mean Fidelity vs a_bound with Std Dev Bands",
    xlabel="log₁₀(a_bound)",
    ylabel="Fidelity"
)

# Select middle dda_bound for cross-section
mid_dda_idx = round(Int, length(dda_bounds)/2)

# Plot mean with error bands
lines!(ax_cross1, log10.(a_bounds), mean_fidelities[:, mid_dda_idx],
       label="Mean", color=:blue, linewidth=3)
band!(ax_cross1, log10.(a_bounds),
      mean_fidelities[:, mid_dda_idx] .- std_fidelities[:, mid_dda_idx],
      mean_fidelities[:, mid_dda_idx] .+ std_fidelities[:, mid_dda_idx],
      color=(:blue, 0.3), label="±1 Std Dev")

# Plot individual seeds
for seed_idx in 1:n_seeds
    lines!(ax_cross1, log10.(a_bounds), fidelities[:, mid_dda_idx, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash)
end

axislegend(ax_cross1, position=:rb)

# 6. Cross-section for dda_bound
ax_cross2 = Axis(f[3, 3:4],
    title="Mean Fidelity vs dda_bound with Std Dev Bands",
    xlabel="log₁₀(dda_bound)",
    ylabel="Fidelity"
)

# Select middle a_bound for cross-section
mid_a_idx = round(Int, length(a_bounds)/2)

lines!(ax_cross2, log10.(dda_bounds), mean_fidelities[mid_a_idx, :],
       label="Mean", color=:red, linewidth=3)
band!(ax_cross2, log10.(dda_bounds),
      mean_fidelities[mid_a_idx, :] .- std_fidelities[mid_a_idx, :],
      mean_fidelities[mid_a_idx, :] .+ std_fidelities[mid_a_idx, :],
      color=(:red, 0.3), label="±1 Std Dev")

# Plot individual seeds
for seed_idx in 1:n_seeds
    lines!(ax_cross2, log10.(dda_bounds), fidelities[mid_a_idx, :, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash)
end

axislegend(ax_cross2, position=:rb)

# Add overall title
Label(f[0, 1:4], "Multi-Seed Toggle Frame Quantum Control: Parameter Sensitivity Analysis",
      fontsize=20, font="bold")

# Display the figure
display(f)

# Print summary statistics
println("\n" * "="^60)
println("SUMMARY STATISTICS (MULTI-SEED - TOGGLE FRAME)")
println("="^60)

max_mean_fidelity = maximum(mean_fidelities)
max_idx = argmax(mean_fidelities)
best_a = a_bounds[max_idx[1]]
best_dda = dda_bounds[max_idx[2]]

println("\nBest mean fidelity: $(Printf.@sprintf("%.6f", max_mean_fidelity))")
println("Best parameters: a_bound = $(Printf.@sprintf("%.3e", best_a)), dda_bound = $(Printf.@sprintf("%.3e", best_dda))")
println("Std dev at best params: $(Printf.@sprintf("%.6f", std_fidelities[max_idx]))")
println("Range at best params: $(Printf.@sprintf("%.6f", fidelity_range[max_idx]))")

# Find parameters with both high mean and low variance
high_quality_mask = (mean_fidelities .> 0.999) .& (std_fidelities .< 0.001)
n_high_quality = sum(high_quality_mask)
println("\nParameter combinations with fidelity > 0.999 AND std < 0.001: $n_high_quality / $(length(mean_fidelities))")

# Identify most stable parameter regions (low variance)
min_std = minimum(std_fidelities)
min_std_idx = argmin(std_fidelities)
println("\nMost stable parameters (lowest std dev):")
println("  a_bound = $(Printf.@sprintf("%.3e", a_bounds[min_std_idx[1]])), dda_bound = $(Printf.@sprintf("%.3e", dda_bounds[min_std_idx[2]]))")
println("  Std dev: $(Printf.@sprintf("%.6f", min_std))")
println("  Mean fidelity: $(Printf.@sprintf("%.6f", mean_fidelities[min_std_idx]))")

# Seed sensitivity analysis
avg_std = mean(std_fidelities)
max_std = maximum(std_fidelities)
max_std_idx = argmax(std_fidelities)
println("\nSeed sensitivity across all parameters:")
println("  Average std dev: $(Printf.@sprintf("%.6f", avg_std))")
println("  Maximum std dev: $(Printf.@sprintf("%.6f", max_std))")
println("  Most sensitive at: a_bound = $(Printf.@sprintf("%.3e", a_bounds[max_std_idx[1]])), dda_bound = $(Printf.@sprintf("%.3e", dda_bounds[max_std_idx[2]]))")
# Out:
# ============================================================
# SUMMARY STATISTICS (MULTI-SEED - TOGGLE FRAME)
# ============================================================
#
# Best mean fidelity: 1.000000
# Best parameters: a_bound = 2.848e+00, dda_bound = 4.329e+00
# Std dev at best params: 0.000000
# Range at best params: 0.000000
#
# Parameter combinations with fidelity > 0.999 AND std < 0.001: 119 / 144
#
# Most stable parameters (lowest std dev):
#   a_bound = 1.520e-01, dda_bound = 1.000e-01
#   Std dev: 0.000000
#   Mean fidelity: 0.964073
#
# Seed sensitivity across all parameters:
#   Average std dev: 0.000300
#   Maximum std dev: 0.015421
#   Most sensitive at: a_bound = 2.848e+00, dda_bound = 1.520e-01

# %%
# Calculate robustness metrics for all trajectories (all seeds) - Toggle Frame
println("\nCalculating robustness metrics for all seeds (Toggle Frame)...")

# Initialize storage for robustness metrics (now with seed dimension)
space_curve_robustness_values = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_x = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_y = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_z = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_avg = zeros(length(a_bounds), length(dda_bounds), n_seeds)

# Calculate robustness for each trajectory
for (i, a_bound) in enumerate(a_bounds)
    for (j, dda_bound) in enumerate(dda_bounds)
        for seed_idx in 1:n_seeds
            if !isnothing(trajectories[i, j, seed_idx])
                traj = trajectories[i, j, seed_idx]
                
                # Space curve robustness (average over all Pauli errors)
                Xerr = space_curve_robustness(traj, U_goal, PAULIS.X)
                Yerr = space_curve_robustness(traj, U_goal, PAULIS.Y)
                Zerr = space_curve_robustness(traj, U_goal, PAULIS.Z)
                space_curve_robustness_values[i, j, seed_idx] = 1-(Xerr + Yerr + Zerr) / 3
                
                # Width robustness
                widths = width_robustness(sys, traj, thresh=0.99)
                width_robustness_x[i, j, seed_idx] = widths[1]
                width_robustness_y[i, j, seed_idx] = widths[2]
                width_robustness_z[i, j, seed_idx] = widths[3]
                width_robustness_avg[i, j, seed_idx] = mean(widths)
                
                println("a=$(Printf.@sprintf("%.3e", a_bound)), dda=$(Printf.@sprintf("%.3e", dda_bound)), seed=$seed_idx: " *
                       "SC_robust=$(Printf.@sprintf("%.4f", space_curve_robustness_values[i, j, seed_idx])), " *
                       "Width_avg=$(Printf.@sprintf("%.4f", width_robustness_avg[i, j, seed_idx]))")
            end
        end
    end
end

# Compute statistics across seeds for robustness metrics
mean_sc_robust = mean(space_curve_robustness_values, dims=3)[:, :, 1]
std_sc_robust = std(space_curve_robustness_values, dims=3)[:, :, 1]
mean_width_robust = mean(width_robustness_avg, dims=3)[:, :, 1]
std_width_robust = std(width_robustness_avg, dims=3)[:, :, 1]

# Create comprehensive robustness visualization
f_robust = Figure(size=(2000, 1600))

# Row 1: Mean Space Curve Robustness
ax_sc_3d = Axis3(f_robust[1, 1:2],
    title="Mean Space Curve Robustness (Toggle Frame)",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)",
    zlabel="SC Robustness",
    aspect=(1, 1, 0.5)
)

x_3d = repeat(log10.(a_bounds), 1, length(dda_bounds))
y_3d = repeat(log10.(dda_bounds)', length(a_bounds), 1)
Makie.surface!(ax_sc_3d, x_3d, y_3d, mean_sc_robust, colormap=:plasma, alpha=0.8)
Makie.contour3d!(ax_sc_3d, x_3d, y_3d, mean_sc_robust, levels=10, linewidth=1, alpha=0.6)

ax_sc_heat = Axis(f_robust[1, 3],
    title="Mean SC Robustness",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_sc = Makie.heatmap!(ax_sc_heat, log10.(a_bounds), log10.(dda_bounds), mean_sc_robust, colormap=:plasma)
Colorbar(f_robust[1, 4], hm_sc, label="Mean SC Robust")

ax_sc_std = Axis(f_robust[1, 5],
    title="SC Robustness Std Dev",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_sc_std = Makie.heatmap!(ax_sc_std, log10.(a_bounds), log10.(dda_bounds), std_sc_robust, colormap=:reds)
Colorbar(f_robust[1, 6], hm_sc_std, label="Std Dev")

# Row 2: Mean Width Robustness
ax_w_3d = Axis3(f_robust[2, 1:2],
    title="Mean Width Robustness (Toggle Frame)",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)",
    zlabel="Width Robustness",
    aspect=(1, 1, 0.5)
)

Makie.surface!(ax_w_3d, x_3d, y_3d, mean_width_robust, colormap=:turbo, alpha=0.8)
Makie.contour3d!(ax_w_3d, x_3d, y_3d, mean_width_robust, levels=10, linewidth=1, alpha=0.6)

ax_w_heat = Axis(f_robust[2, 3],
    title="Mean Width Robustness",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_w = Makie.heatmap!(ax_w_heat, log10.(a_bounds), log10.(dda_bounds), mean_width_robust, colormap=:turbo)
Colorbar(f_robust[2, 4], hm_w, label="Mean Width")

ax_w_std = Axis(f_robust[2, 5],
    title="Width Robustness Std Dev",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_w_std = Makie.heatmap!(ax_w_std, log10.(a_bounds), log10.(dda_bounds), std_width_robust, colormap=:reds)
Colorbar(f_robust[2, 6], hm_w_std, label="Std Dev")

# Row 3: Correlation analysis
ax_corr = Axis(f_robust[3, 1:3],
    title="Correlation: Space Curve vs Width Robustness (All Seeds)",
    xlabel="Space Curve Robustness",
    ylabel="Width Robustness"
)

# Flatten all seeds for correlation plot
sc_all = vec(space_curve_robustness_values)
w_all = vec(width_robustness_avg)
fid_all = vec(fidelities)

# Create scatter with seed coloring
colors_seeds = [:red, :blue, :green, :orange, :purple]
for seed_idx in 1:n_seeds
    sc_seed = 1 .- vec(space_curve_robustness_values[:, :, seed_idx])
    w_seed = vec(width_robustness_avg[:, :, seed_idx])
    Makie.scatter!(ax_corr, sc_seed, w_seed,
              label="Seed $seed_idx",
              color=colors_seeds[seed_idx],
              markersize=6, alpha=0.6)
end

correlation = cor(sc_all, w_all)
text!(ax_corr, 0.05, 0.95, text="Overall Correlation: $(Printf.@sprintf("%.3f", correlation))",
      space=:relative, fontsize=14, font="bold")
axislegend(ax_corr, position=:rb)

# Row 3: Summary statistics
ax_summary = Axis(f_robust[3, 4:6],
    title="Multi-Seed Robustness Summary"
)
hidedecorations!(ax_summary)
hidespines!(ax_summary)

summary_text = """
Space Curve Robustness:
  Mean across all: $(Printf.@sprintf("%.4f", mean(mean_sc_robust)))
  Std across params: $(Printf.@sprintf("%.4f", std(mean_sc_robust)))
  Avg std across seeds: $(Printf.@sprintf("%.4f", mean(std_sc_robust)))
  Min mean: $(Printf.@sprintf("%.4f", minimum(mean_sc_robust)))
  Max mean: $(Printf.@sprintf("%.4f", maximum(mean_sc_robust)))

Width Robustness:
  Mean across all: $(Printf.@sprintf("%.4f", mean(mean_width_robust)))
  Std across params: $(Printf.@sprintf("%.4f", std(mean_width_robust)))
  Avg std across seeds: $(Printf.@sprintf("%.4f", mean(std_width_robust)))
  Min mean: $(Printf.@sprintf("%.4f", minimum(mean_width_robust)))
  Max mean: $(Printf.@sprintf("%.4f", maximum(mean_width_robust)))

Seed Variability:
  Params with high SC std (>0.01): $(sum(std_sc_robust .> 0.01))
  Params with high W std (>0.01): $(sum(std_width_robust .> 0.01))

Best Combined (Fidelity + Robustness):
  Using mean fidelity > 0.999 & mean width > 0.1
  Count: $(sum((mean_fidelities .> 0.999) .& (mean_width_robust .> 0.1)))
"""

text!(ax_summary, 0.05, 0.5, text=summary_text,
      space=:relative, fontsize=11, font="monospace")

# Row 4: Cross-sections with seed bands
mid_dda = round(Int, length(dda_bounds)/2)
mid_a = round(Int, length(a_bounds)/2)

ax_cross_sc = Axis(f_robust[4, 1:3],
    title="Space Curve Robustness vs a_bound (with seed variability)",
    xlabel="log₁₀(a_bound)",
    ylabel="SC Robustness"
)

lines!(ax_cross_sc, log10.(a_bounds), mean_sc_robust[:, mid_dda],
       label="Mean", color=:blue, linewidth=3)
band!(ax_cross_sc, log10.(a_bounds),
      mean_sc_robust[:, mid_dda] .- std_sc_robust[:, mid_dda],
      mean_sc_robust[:, mid_dda] .+ std_sc_robust[:, mid_dda],
      color=(:blue, 0.3), label="±1 Std")

for seed_idx in 1:n_seeds
    lines!(ax_cross_sc, log10.(a_bounds), space_curve_robustness_values[:, mid_dda, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash, color=colors_seeds[seed_idx])
end
axislegend(ax_cross_sc, position=:rt)

ax_cross_w = Axis(f_robust[4, 4:6],
    title="Width Robustness vs dda_bound (with seed variability)",
    xlabel="log₁₀(dda_bound)",
    ylabel="Width Robustness"
)

lines!(ax_cross_w, log10.(dda_bounds), mean_width_robust[mid_a, :],
       label="Mean", color=:red, linewidth=3)
band!(ax_cross_w, log10.(dda_bounds),
      mean_width_robust[mid_a, :] .- std_width_robust[mid_a, :],
      mean_width_robust[mid_a, :] .+ std_width_robust[mid_a, :],
      color=(:red, 0.3), label="±1 Std")

for seed_idx in 1:n_seeds
    lines!(ax_cross_w, log10.(dda_bounds), width_robustness_avg[mid_a, :, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash, color=colors_seeds[seed_idx])
end
axislegend(ax_cross_w, position=:lt)

Label(f_robust[0, :], "Multi-Seed Robustness Analysis (Toggle Frame): Parameter Sensitivity",
      fontsize=20, font="bold")

display(f_robust)

println("\nMulti-seed robustness analysis complete (Toggle Frame)!")
# Out:
# Calculating robustness metrics for all seeds (Toggle Frame)...
# a=1.000e-01, dda=1.000e-01, seed=1: SC_robust=0.1192, Width_avg=0.0001
# a=1.000e-01, dda=1.000e-01, seed=2: SC_robust=0.1192, Width_avg=0.0001
# a=1.000e-01, dda=1.520e-01, seed=1: SC_robust=0.1214, Width_avg=0.0001
# a=1.000e-01, dda=1.520e-01, seed=2: SC_robust=0.1214, Width_avg=0.0001
# a=1.000e-01, dda=2.310e-01, seed=1: SC_robust=0.1236, Width_avg=0.0001
# a=1.000e-01, dda=2.310e-01, seed=2: SC_robust=0.1236, Width_avg=0.0001
# a=1.000e-01, dda=3.511e-01, seed=1: SC_robust=0.1244, Width_avg=0.0001
# a=1.000e-01, dda=3.511e-01, seed=2: SC_robust=0.1244, Width_avg=0.0001
# a=1.000e-01, dda=5.337e-01, seed=1: SC_robust=0.1257, Width_avg=0.0001
# a=1.000e-01, dda=5.337e-01, seed=2: SC_robust=0.1257, Width_avg=0.0001
# a=1.000e-01, dda=8.111e-01, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=8.111e-01, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.233e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.233e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.874e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.874e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=2.848e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=2.848e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=4.329e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=4.329e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=6.579e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=6.579e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.000e+01, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.000e+01, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.520e-01, dda=1.000e-01, seed=1: SC_robust=0.2404, Width_avg=0.0001
# a=1.520e-01, dda=1.000e-01, seed=2: SC_robust=0.2404, Width_avg=0.0001
# a=1.520e-01, dda=1.520e-01, seed=1: SC_robust=0.2470, Width_avg=0.0001
# a=1.520e-01, dda=1.520e-01, seed=2: SC_robust=0.2470, Width_avg=0.0001
# a=1.520e-01, dda=2.310e-01, seed=1: SC_robust=0.2507, Width_avg=0.0001
# a=1.520e-01, dda=2.310e-01, seed=2: SC_robust=0.2507, Width_avg=0.0001
# a=1.520e-01, dda=3.511e-01, seed=1: SC_robust=0.2545, Width_avg=0.0218
# a=1.520e-01, dda=3.511e-01, seed=2: SC_robust=0.2545, Width_avg=0.0218
# a=1.520e-01, dda=5.337e-01, seed=1: SC_robust=0.2559, Width_avg=0.0106
# a=1.520e-01, dda=5.337e-01, seed=2: SC_robust=0.2559, Width_avg=0.0218
# a=1.520e-01, dda=8.111e-01, seed=1: SC_robust=0.2580, Width_avg=0.0207
# a=1.520e-01, dda=8.111e-01, seed=2: SC_robust=0.2580, Width_avg=0.0207
# a=1.520e-01, dda=1.233e+00, seed=1: SC_robust=0.2516, Width_avg=0.0219
# a=1.520e-01, dda=1.233e+00, seed=2: SC_robust=0.2586, Width_avg=0.0200
# a=1.520e-01, dda=1.874e+00, seed=1: SC_robust=0.2602, Width_avg=0.0200
# a=1.520e-01, dda=1.874e+00, seed=2: SC_robust=0.2581, Width_avg=0.0202
# a=1.520e-01, dda=2.848e+00, seed=1: SC_robust=0.2588, Width_avg=0.0204
# a=1.520e-01, dda=2.848e+00, seed=2: SC_robust=0.2592, Width_avg=0.0199
# a=1.520e-01, dda=4.329e+00, seed=1: SC_robust=0.2557, Width_avg=0.0207
# a=1.520e-01, dda=4.329e+00, seed=2: SC_robust=0.2587, Width_avg=0.0203
# a=1.520e-01, dda=6.579e+00, seed=1: SC_robust=0.2574, Width_avg=0.0204
# a=1.520e-01, dda=6.579e+00, seed=2: SC_robust=0.2584, Width_avg=0.0202
# a=1.520e-01, dda=1.000e+01, seed=1: SC_robust=0.2592, Width_avg=0.0199
# a=1.520e-01, dda=1.000e+01, seed=2: SC_robust=0.2587, Width_avg=0.0208
# a=2.310e-01, dda=1.000e-01, seed=1: SC_robust=0.3853, Width_avg=0.0224
# a=2.310e-01, dda=1.000e-01, seed=2: SC_robust=0.3852, Width_avg=0.0205
# a=2.310e-01, dda=1.520e-01, seed=1: SC_robust=0.4122, Width_avg=0.0211
# a=2.310e-01, dda=1.520e-01, seed=2: SC_robust=0.4122, Width_avg=0.0211
# a=2.310e-01, dda=2.310e-01, seed=1: SC_robust=0.4240, Width_avg=0.0225
# a=2.310e-01, dda=2.310e-01, seed=2: SC_robust=0.4240, Width_avg=0.0218
# a=2.310e-01, dda=3.511e-01, seed=1: SC_robust=0.4326, Width_avg=0.0223
# a=2.310e-01, dda=3.511e-01, seed=2: SC_robust=0.4326, Width_avg=0.0223
# a=2.310e-01, dda=5.337e-01, seed=1: SC_robust=0.4426, Width_avg=0.0229
# a=2.310e-01, dda=5.337e-01, seed=2: SC_robust=0.4426, Width_avg=0.0235
# a=2.310e-01, dda=8.111e-01, seed=1: SC_robust=0.4482, Width_avg=0.0233
# a=2.310e-01, dda=8.111e-01, seed=2: SC_robust=0.4487, Width_avg=0.0238
# a=2.310e-01, dda=1.233e+00, seed=1: SC_robust=0.4546, Width_avg=0.0236
# a=2.310e-01, dda=1.233e+00, seed=2: SC_robust=0.4166, Width_avg=0.0222
# a=2.310e-01, dda=1.874e+00, seed=1: SC_robust=0.4580, Width_avg=0.0237
# a=2.310e-01, dda=1.874e+00, seed=2: SC_robust=0.4478, Width_avg=0.0230
# a=2.310e-01, dda=2.848e+00, seed=1: SC_robust=0.4538, Width_avg=0.0234
# a=2.310e-01, dda=2.848e+00, seed=2: SC_robust=0.4586, Width_avg=0.0238
# a=2.310e-01, dda=4.329e+00, seed=1: SC_robust=0.4588, Width_avg=0.0243
# a=2.310e-01, dda=4.329e+00, seed=2: SC_robust=0.4586, Width_avg=0.0238
# a=2.310e-01, dda=6.579e+00, seed=1: SC_robust=0.4225, Width_avg=0.0233
# a=2.310e-01, dda=6.579e+00, seed=2: SC_robust=0.4489, Width_avg=0.0231
# a=2.310e-01, dda=1.000e+01, seed=1: SC_robust=0.4588, Width_avg=0.0243
# a=2.310e-01, dda=1.000e+01, seed=2: SC_robust=0.3663, Width_avg=0.0001
# a=3.511e-01, dda=1.000e-01, seed=1: SC_robust=0.4551, Width_avg=0.0230
# a=3.511e-01, dda=1.000e-01, seed=2: SC_robust=0.4551, Width_avg=0.0241
# a=3.511e-01, dda=1.520e-01, seed=1: SC_robust=0.5364, Width_avg=0.0263
# a=3.511e-01, dda=1.520e-01, seed=2: SC_robust=0.5364, Width_avg=0.0271
# a=3.511e-01, dda=2.310e-01, seed=1: SC_robust=0.5377, Width_avg=0.0270
# a=3.511e-01, dda=2.310e-01, seed=2: SC_robust=0.5377, Width_avg=0.0270
# a=3.511e-01, dda=3.511e-01, seed=1: SC_robust=0.5854, Width_avg=0.0312
# a=3.511e-01, dda=3.511e-01, seed=2: SC_robust=0.5639, Width_avg=0.0289
# a=3.511e-01, dda=5.337e-01, seed=1: SC_robust=0.6254, Width_avg=0.0375
# a=3.511e-01, dda=5.337e-01, seed=2: SC_robust=0.6324, Width_avg=0.0376
# a=3.511e-01, dda=8.111e-01, seed=1: SC_robust=0.6499, Width_avg=0.0378
# a=3.511e-01, dda=8.111e-01, seed=2: SC_robust=0.6466, Width_avg=0.0373
# a=3.511e-01, dda=1.233e+00, seed=1: SC_robust=0.6624, Width_avg=0.0410
# a=3.511e-01, dda=1.233e+00, seed=2: SC_robust=0.6320, Width_avg=0.0364
# a=3.511e-01, dda=1.874e+00, seed=1: SC_robust=0.6125, Width_avg=0.0463
# a=3.511e-01, dda=1.874e+00, seed=2: SC_robust=0.6125, Width_avg=0.0463
# a=3.511e-01, dda=2.848e+00, seed=1: SC_robust=0.6222, Width_avg=0.0494
# a=3.511e-01, dda=2.848e+00, seed=2: SC_robust=0.6638, Width_avg=0.0367
# a=3.511e-01, dda=4.329e+00, seed=1: SC_robust=0.6618, Width_avg=0.0302
# a=3.511e-01, dda=4.329e+00, seed=2: SC_robust=0.6679, Width_avg=0.0391
# a=3.511e-01, dda=6.579e+00, seed=1: SC_robust=0.6629, Width_avg=0.0371
# a=3.511e-01, dda=6.579e+00, seed=2: SC_robust=0.6623, Width_avg=0.0383
# a=3.511e-01, dda=1.000e+01, seed=1: SC_robust=0.6619, Width_avg=0.0373
# a=3.511e-01, dda=1.000e+01, seed=2: SC_robust=0.6632, Width_avg=0.0365
# a=5.337e-01, dda=1.000e-01, seed=1: SC_robust=0.4750, Width_avg=0.0257
# a=5.337e-01, dda=1.000e-01, seed=2: SC_robust=0.4498, Width_avg=0.0215
# a=5.337e-01, dda=1.520e-01, seed=1: SC_robust=0.5890, Width_avg=0.0361
# a=5.337e-01, dda=1.520e-01, seed=2: SC_robust=0.6204, Width_avg=0.0388
# a=5.337e-01, dda=2.310e-01, seed=1: SC_robust=0.6642, Width_avg=0.0365
# a=5.337e-01, dda=2.310e-01, seed=2: SC_robust=0.6827, Width_avg=0.0433
# a=5.337e-01, dda=3.511e-01, seed=1: SC_robust=0.7057, Width_avg=0.0621
# a=5.337e-01, dda=3.511e-01, seed=2: SC_robust=0.6951, Width_avg=0.0634
# a=5.337e-01, dda=5.337e-01, seed=1: SC_robust=0.7891, Width_avg=0.0560
# a=5.337e-01, dda=5.337e-01, seed=2: SC_robust=0.7943, Width_avg=0.0566
# a=5.337e-01, dda=8.111e-01, seed=1: SC_robust=0.8548, Width_avg=0.0744
# a=5.337e-01, dda=8.111e-01, seed=2: SC_robust=0.8511, Width_avg=0.0739
# a=5.337e-01, dda=1.233e+00, seed=1: SC_robust=0.8653, Width_avg=0.0831
# a=5.337e-01, dda=1.233e+00, seed=2: SC_robust=0.8646, Width_avg=0.0832
# a=5.337e-01, dda=1.874e+00, seed=1: SC_robust=0.8424, Width_avg=0.0708
# a=5.337e-01, dda=1.874e+00, seed=2: SC_robust=0.8730, Width_avg=0.0871
# a=5.337e-01, dda=2.848e+00, seed=1: SC_robust=0.8727, Width_avg=0.0852
# a=5.337e-01, dda=2.848e+00, seed=2: SC_robust=0.8781, Width_avg=0.0841
# a=5.337e-01, dda=4.329e+00, seed=1: SC_robust=0.8835, Width_avg=0.0868
# a=5.337e-01, dda=4.329e+00, seed=2: SC_robust=0.8739, Width_avg=0.0826
# a=5.337e-01, dda=6.579e+00, seed=1: SC_robust=0.8822, Width_avg=0.0862
# a=5.337e-01, dda=6.579e+00, seed=2: SC_robust=0.8717, Width_avg=0.0834
# a=5.337e-01, dda=1.000e+01, seed=1: SC_robust=0.8545, Width_avg=0.0803
# a=5.337e-01, dda=1.000e+01, seed=2: SC_robust=0.8557, Width_avg=0.0786
# a=8.111e-01, dda=1.000e-01, seed=1: SC_robust=0.4748, Width_avg=0.0240
# a=8.111e-01, dda=1.000e-01, seed=2: SC_robust=0.4748, Width_avg=0.0240
# a=8.111e-01, dda=1.520e-01, seed=1: SC_robust=0.6290, Width_avg=0.0425
# a=8.111e-01, dda=1.520e-01, seed=2: SC_robust=0.6204, Width_avg=0.0388
# a=8.111e-01, dda=2.310e-01, seed=1: SC_robust=0.7029, Width_avg=0.0454
# a=8.111e-01, dda=2.310e-01, seed=2: SC_robust=0.7032, Width_avg=0.0454
# a=8.111e-01, dda=3.511e-01, seed=1: SC_robust=0.7153, Width_avg=0.0446
# a=8.111e-01, dda=3.511e-01, seed=2: SC_robust=0.8135, Width_avg=0.0681
# a=8.111e-01, dda=5.337e-01, seed=1: SC_robust=0.8647, Width_avg=0.0910
# a=8.111e-01, dda=5.337e-01, seed=2: SC_robust=0.9090, Width_avg=0.1393
# a=8.111e-01, dda=8.111e-01, seed=1: SC_robust=0.9511, Width_avg=0.1355
# a=8.111e-01, dda=8.111e-01, seed=2: SC_robust=0.9597, Width_avg=0.1553
# a=8.111e-01, dda=1.233e+00, seed=1: SC_robust=0.9811, Width_avg=0.1669
# a=8.111e-01, dda=1.233e+00, seed=2: SC_robust=0.9825, Width_avg=0.1756
# a=8.111e-01, dda=1.874e+00, seed=1: SC_robust=0.9753, Width_avg=0.1639
# a=8.111e-01, dda=1.874e+00, seed=2: SC_robust=0.9759, Width_avg=0.1547
# a=8.111e-01, dda=2.848e+00, seed=1: SC_robust=0.9724, Width_avg=0.1662
# a=8.111e-01, dda=2.848e+00, seed=2: SC_robust=0.9766, Width_avg=0.1649
# a=8.111e-01, dda=4.329e+00, seed=1: SC_robust=0.9844, Width_avg=0.1609
# a=8.111e-01, dda=4.329e+00, seed=2: SC_robust=0.9811, Width_avg=0.1616
# a=8.111e-01, dda=6.579e+00, seed=1: SC_robust=0.9765, Width_avg=0.1642
# a=8.111e-01, dda=6.579e+00, seed=2: SC_robust=0.9771, Width_avg=0.1664
# a=8.111e-01, dda=1.000e+01, seed=1: SC_robust=0.9809, Width_avg=0.1614
# a=8.111e-01, dda=1.000e+01, seed=2: SC_robust=0.9755, Width_avg=0.1642
# a=1.233e+00, dda=1.000e-01, seed=1: SC_robust=0.4636, Width_avg=0.0226
# a=1.233e+00, dda=1.000e-01, seed=2: SC_robust=0.4791, Width_avg=0.0298
# a=1.233e+00, dda=1.520e-01, seed=1: SC_robust=0.6327, Width_avg=0.0441
# a=1.233e+00, dda=1.520e-01, seed=2: SC_robust=0.6204, Width_avg=0.0388
# a=1.233e+00, dda=2.310e-01, seed=1: SC_robust=0.7032, Width_avg=0.0454
# a=1.233e+00, dda=2.310e-01, seed=2: SC_robust=0.6984, Width_avg=0.0446
# a=1.233e+00, dda=3.511e-01, seed=1: SC_robust=0.7153, Width_avg=0.0451
# a=1.233e+00, dda=3.511e-01, seed=2: SC_robust=0.8100, Width_avg=0.0690
# a=1.233e+00, dda=5.337e-01, seed=1: SC_robust=0.9089, Width_avg=0.1156
# a=1.233e+00, dda=5.337e-01, seed=2: SC_robust=0.9123, Width_avg=0.1001
# a=1.233e+00, dda=8.111e-01, seed=1: SC_robust=0.9696, Width_avg=0.1527
# a=1.233e+00, dda=8.111e-01, seed=2: SC_robust=0.9688, Width_avg=0.1516
# a=1.233e+00, dda=1.233e+00, seed=1: SC_robust=0.9821, Width_avg=0.1756
# a=1.233e+00, dda=1.233e+00, seed=2: SC_robust=0.9817, Width_avg=0.1771
# a=1.233e+00, dda=1.874e+00, seed=1: SC_robust=0.9847, Width_avg=0.1688
# a=1.233e+00, dda=1.874e+00, seed=2: SC_robust=0.9857, Width_avg=0.1695
# a=1.233e+00, dda=2.848e+00, seed=1: SC_robust=0.9820, Width_avg=0.1853
# a=1.233e+00, dda=2.848e+00, seed=2: SC_robust=0.9860, Width_avg=0.1838
# a=1.233e+00, dda=4.329e+00, seed=1: SC_robust=0.9854, Width_avg=0.1680
# a=1.233e+00, dda=4.329e+00, seed=2: SC_robust=0.9852, Width_avg=0.1726
# a=1.233e+00, dda=6.579e+00, seed=1: SC_robust=0.9799, Width_avg=0.1853
# a=1.233e+00, dda=6.579e+00, seed=2: SC_robust=0.9854, Width_avg=0.1807
# a=1.233e+00, dda=1.000e+01, seed=1: SC_robust=0.9864, Width_avg=0.1992
# a=1.233e+00, dda=1.000e+01, seed=2: SC_robust=0.9860, Width_avg=0.1783
# a=1.874e+00, dda=1.000e-01, seed=1: SC_robust=0.4748, Width_avg=0.0240
# a=1.874e+00, dda=1.000e-01, seed=2: SC_robust=0.4627, Width_avg=0.0242
# a=1.874e+00, dda=1.520e-01, seed=1: SC_robust=0.6232, Width_avg=0.0368
# a=1.874e+00, dda=1.520e-01, seed=2: SC_robust=0.4053, Width_avg=0.0239
# a=1.874e+00, dda=2.310e-01, seed=1: SC_robust=0.6981, Width_avg=0.0445
# a=1.874e+00, dda=2.310e-01, seed=2: SC_robust=0.6980, Width_avg=0.0448
# a=1.874e+00, dda=3.511e-01, seed=1: SC_robust=0.7153, Width_avg=0.0451
# a=1.874e+00, dda=3.511e-01, seed=2: SC_robust=0.7153, Width_avg=0.0446
# a=1.874e+00, dda=5.337e-01, seed=1: SC_robust=0.8647, Width_avg=0.0910
# a=1.874e+00, dda=5.337e-01, seed=2: SC_robust=0.8697, Width_avg=0.0797
# a=1.874e+00, dda=8.111e-01, seed=1: SC_robust=0.9691, Width_avg=0.1561
# a=1.874e+00, dda=8.111e-01, seed=2: SC_robust=0.9698, Width_avg=0.1527
# a=1.874e+00, dda=1.233e+00, seed=1: SC_robust=0.9742, Width_avg=0.1593
# a=1.874e+00, dda=1.233e+00, seed=2: SC_robust=0.9831, Width_avg=0.2017
# a=1.874e+00, dda=1.874e+00, seed=1: SC_robust=0.9790, Width_avg=0.1363
# a=1.874e+00, dda=1.874e+00, seed=2: SC_robust=0.9845, Width_avg=0.2350
# a=1.874e+00, dda=2.848e+00, seed=1: SC_robust=0.9863, Width_avg=0.1458
# a=1.874e+00, dda=2.848e+00, seed=2: SC_robust=0.9795, Width_avg=0.1624
# a=1.874e+00, dda=4.329e+00, seed=1: SC_robust=0.9832, Width_avg=0.1267
# a=1.874e+00, dda=4.329e+00, seed=2: SC_robust=0.9885, Width_avg=0.1871
# a=1.874e+00, dda=6.579e+00, seed=1: SC_robust=0.9860, Width_avg=0.1787
# a=1.874e+00, dda=6.579e+00, seed=2: SC_robust=0.9826, Width_avg=0.1813
# a=1.874e+00, dda=1.000e+01, seed=1: SC_robust=0.9878, Width_avg=0.1809
# a=1.874e+00, dda=1.000e+01, seed=2: SC_robust=0.9875, Width_avg=0.1804
# a=2.848e+00, dda=1.000e-01, seed=1: SC_robust=0.4748, Width_avg=0.0257
# a=2.848e+00, dda=1.000e-01, seed=2: SC_robust=0.4748, Width_avg=0.0295
# a=2.848e+00, dda=1.520e-01, seed=1: SC_robust=0.4351, Width_avg=0.0001
# a=2.848e+00, dda=1.520e-01, seed=2: SC_robust=0.6464, Width_avg=0.0837
# a=2.848e+00, dda=2.310e-01, seed=1: SC_robust=0.7029, Width_avg=0.0454
# a=2.848e+00, dda=2.310e-01, seed=2: SC_robust=0.6895, Width_avg=0.0237
# a=2.848e+00, dda=3.511e-01, seed=1: SC_robust=0.7145, Width_avg=0.0440
# a=2.848e+00, dda=3.511e-01, seed=2: SC_robust=0.8129, Width_avg=0.0715
# a=2.848e+00, dda=5.337e-01, seed=1: SC_robust=0.8579, Width_avg=0.0806
# a=2.848e+00, dda=5.337e-01, seed=2: SC_robust=0.8804, Width_avg=0.0839
# a=2.848e+00, dda=8.111e-01, seed=1: SC_robust=0.9588, Width_avg=0.1666
# a=2.848e+00, dda=8.111e-01, seed=2: SC_robust=0.9650, Width_avg=0.1516
# a=2.848e+00, dda=1.233e+00, seed=1: SC_robust=0.9817, Width_avg=0.2092
# a=2.848e+00, dda=1.233e+00, seed=2: SC_robust=0.9770, Width_avg=0.1729
# a=2.848e+00, dda=1.874e+00, seed=1: SC_robust=0.9847, Width_avg=0.1377
# a=2.848e+00, dda=1.874e+00, seed=2: SC_robust=0.9853, Width_avg=0.1689
# a=2.848e+00, dda=2.848e+00, seed=1: SC_robust=0.9818, Width_avg=0.1382
# a=2.848e+00, dda=2.848e+00, seed=2: SC_robust=0.9832, Width_avg=0.1747
# a=2.848e+00, dda=4.329e+00, seed=1: SC_robust=0.9825, Width_avg=0.1601
# a=2.848e+00, dda=4.329e+00, seed=2: SC_robust=0.9859, Width_avg=0.1686
# a=2.848e+00, dda=6.579e+00, seed=1: SC_robust=0.9454, Width_avg=0.2080
# a=2.848e+00, dda=6.579e+00, seed=2: SC_robust=0.9848, Width_avg=0.1483
# a=2.848e+00, dda=1.000e+01, seed=1: SC_robust=0.9864, Width_avg=0.1779
# a=2.848e+00, dda=1.000e+01, seed=2: SC_robust=0.9839, Width_avg=0.1503
# a=4.329e+00, dda=1.000e-01, seed=1: SC_robust=0.4629, Width_avg=0.0226
# a=4.329e+00, dda=1.000e-01, seed=2: SC_robust=0.4747, Width_avg=0.0257
# a=4.329e+00, dda=1.520e-01, seed=1: SC_robust=0.5206, Width_avg=0.0269
# a=4.329e+00, dda=1.520e-01, seed=2: SC_robust=0.6464, Width_avg=0.0871
# a=4.329e+00, dda=2.310e-01, seed=1: SC_robust=0.6906, Width_avg=0.0441
# a=4.329e+00, dda=2.310e-01, seed=2: SC_robust=0.6178, Width_avg=0.0390
# a=4.329e+00, dda=3.511e-01, seed=1: SC_robust=0.7153, Width_avg=0.0451
# a=4.329e+00, dda=3.511e-01, seed=2: SC_robust=0.7010, Width_avg=0.0438
# a=4.329e+00, dda=5.337e-01, seed=1: SC_robust=0.8647, Width_avg=0.0910
# a=4.329e+00, dda=5.337e-01, seed=2: SC_robust=0.8361, Width_avg=0.0942
# a=4.329e+00, dda=8.111e-01, seed=1: SC_robust=0.9713, Width_avg=0.1726
# a=4.329e+00, dda=8.111e-01, seed=2: SC_robust=0.9690, Width_avg=0.1860
# a=4.329e+00, dda=1.233e+00, seed=1: SC_robust=0.9827, Width_avg=0.1647
# a=4.329e+00, dda=1.233e+00, seed=2: SC_robust=0.9822, Width_avg=0.1428
# a=4.329e+00, dda=1.874e+00, seed=1: SC_robust=0.9854, Width_avg=0.1895
# a=4.329e+00, dda=1.874e+00, seed=2: SC_robust=0.9834, Width_avg=0.1553
# a=4.329e+00, dda=2.848e+00, seed=1: SC_robust=0.9853, Width_avg=0.1522
# a=4.329e+00, dda=2.848e+00, seed=2: SC_robust=0.9849, Width_avg=0.1468
# a=4.329e+00, dda=4.329e+00, seed=1: SC_robust=0.9853, Width_avg=0.1511
# a=4.329e+00, dda=4.329e+00, seed=2: SC_robust=0.9854, Width_avg=0.1567
# a=4.329e+00, dda=6.579e+00, seed=1: SC_robust=0.9858, Width_avg=0.1348
# a=4.329e+00, dda=6.579e+00, seed=2: SC_robust=0.9847, Width_avg=0.1333
# a=4.329e+00, dda=1.000e+01, seed=1: SC_robust=0.9882, Width_avg=0.1707
# a=4.329e+00, dda=1.000e+01, seed=2: SC_robust=0.9848, Width_avg=0.1699
# a=6.579e+00, dda=1.000e-01, seed=1: SC_robust=0.4748, Width_avg=0.0257
# a=6.579e+00, dda=1.000e-01, seed=2: SC_robust=0.4748, Width_avg=0.0257
# a=6.579e+00, dda=1.520e-01, seed=1: SC_robust=0.6204, Width_avg=0.0396
# a=6.579e+00, dda=1.520e-01, seed=2: SC_robust=0.6339, Width_avg=0.0449
# a=6.579e+00, dda=2.310e-01, seed=1: SC_robust=0.6962, Width_avg=0.0442
# a=6.579e+00, dda=2.310e-01, seed=2: SC_robust=0.6980, Width_avg=0.0448
# a=6.579e+00, dda=3.511e-01, seed=1: SC_robust=0.8109, Width_avg=0.0783
# a=6.579e+00, dda=3.511e-01, seed=2: SC_robust=0.8029, Width_avg=0.0631
# a=6.579e+00, dda=5.337e-01, seed=1: SC_robust=0.8618, Width_avg=0.0854
# a=6.579e+00, dda=5.337e-01, seed=2: SC_robust=0.8998, Width_avg=0.1988
# a=6.579e+00, dda=8.111e-01, seed=1: SC_robust=0.9693, Width_avg=0.1209
# a=6.579e+00, dda=8.111e-01, seed=2: SC_robust=0.9423, Width_avg=0.1695
# a=6.579e+00, dda=1.233e+00, seed=1: SC_robust=0.9721, Width_avg=0.1569
# a=6.579e+00, dda=1.233e+00, seed=2: SC_robust=0.9864, Width_avg=0.1260
# a=6.579e+00, dda=1.874e+00, seed=1: SC_robust=0.9481, Width_avg=0.2151
# a=6.579e+00, dda=1.874e+00, seed=2: SC_robust=0.9849, Width_avg=0.1589
# a=6.579e+00, dda=2.848e+00, seed=1: SC_robust=0.9591, Width_avg=0.1545
# a=6.579e+00, dda=2.848e+00, seed=2: SC_robust=0.9848, Width_avg=0.1458
# a=6.579e+00, dda=4.329e+00, seed=1: SC_robust=0.9836, Width_avg=0.1484
# a=6.579e+00, dda=4.329e+00, seed=2: SC_robust=0.9860, Width_avg=0.1923
# a=6.579e+00, dda=6.579e+00, seed=1: SC_robust=0.9689, Width_avg=0.1739
# a=6.579e+00, dda=6.579e+00, seed=2: SC_robust=0.9850, Width_avg=0.1567
# a=6.579e+00, dda=1.000e+01, seed=1: SC_robust=0.9833, Width_avg=0.1454
# a=6.579e+00, dda=1.000e+01, seed=2: SC_robust=0.9846, Width_avg=0.1552
# a=1.000e+01, dda=1.000e-01, seed=1: SC_robust=0.4748, Width_avg=0.0278
# a=1.000e+01, dda=1.000e-01, seed=2: SC_robust=0.4748, Width_avg=0.0295
# a=1.000e+01, dda=1.520e-01, seed=1: SC_robust=0.6204, Width_avg=0.0377
# a=1.000e+01, dda=1.520e-01, seed=2: SC_robust=0.6205, Width_avg=0.0376
# a=1.000e+01, dda=2.310e-01, seed=1: SC_robust=0.7032, Width_avg=0.0452
# a=1.000e+01, dda=2.310e-01, seed=2: SC_robust=0.5256, Width_avg=0.0418
# a=1.000e+01, dda=3.511e-01, seed=1: SC_robust=0.8109, Width_avg=0.0787
# a=1.000e+01, dda=3.511e-01, seed=2: SC_robust=0.8137, Width_avg=0.0682
# a=1.000e+01, dda=5.337e-01, seed=1: SC_robust=0.4905, Width_avg=0.0366
# a=1.000e+01, dda=5.337e-01, seed=2: SC_robust=0.6857, Width_avg=0.0489
# a=1.000e+01, dda=8.111e-01, seed=1: SC_robust=0.6111, Width_avg=0.0369
# a=1.000e+01, dda=8.111e-01, seed=2: SC_robust=0.9690, Width_avg=0.1517
# a=1.000e+01, dda=1.233e+00, seed=1: SC_robust=0.9539, Width_avg=0.1379
# a=1.000e+01, dda=1.233e+00, seed=2: SC_robust=0.9714, Width_avg=0.1427
# a=1.000e+01, dda=1.874e+00, seed=1: SC_robust=0.9576, Width_avg=0.1601
# a=1.000e+01, dda=1.874e+00, seed=2: SC_robust=0.9733, Width_avg=0.1494
# a=1.000e+01, dda=2.848e+00, seed=1: SC_robust=0.8985, Width_avg=0.1756
# a=1.000e+01, dda=2.848e+00, seed=2: SC_robust=0.9850, Width_avg=0.1530
# a=1.000e+01, dda=4.329e+00, seed=1: SC_robust=0.9052, Width_avg=0.1778
# a=1.000e+01, dda=4.329e+00, seed=2: SC_robust=0.9859, Width_avg=0.1823
# a=1.000e+01, dda=6.579e+00, seed=1: SC_robust=0.9170, Width_avg=0.1400
# a=1.000e+01, dda=6.579e+00, seed=2: SC_robust=0.9652, Width_avg=0.1498
# a=1.000e+01, dda=1.000e+01, seed=1: SC_robust=0.9269, Width_avg=0.1693
# a=1.000e+01, dda=1.000e+01, seed=2: SC_robust=0.9300, Width_avg=0.1922
#
# Multi-seed robustness analysis complete (Toggle Frame)!

# %%
using Dates
output_dir = joinpath(@__DIR__, "plots", "a_dda_landscape")
mkpath(output_dir)

# Save with timestamp
timestamp = Dates.format(now(), "yyyymmdd_HHMMSS")
save(joinpath(output_dir, "multi_seed_robustness_analysis_$(timestamp).png"), f_robust, px_per_unit=2)

println("Saved robustness analysis figure to: $(output_dir)")
# Out:
# Saved robustness analysis figure to: /Users/samafine1/Documents/research/pulses/project/notebooks/src/plots/a_dda_landscape

# %%
using JLD2

# Create the data directory
data_dir = joinpath(@__DIR__, "plots", "a_dda_landscape")
mkpath(data_dir)

# Save all trajectory data
data_file = joinpath(data_dir, "trajectory_data.jld2")
@save data_file trajectories fidelities convergence_times final_costs a_bounds dda_bounds n_seeds seed_values space_curve_robustness_values width_robustness_x width_robustness_y width_robustness_z width_robustness_avg mean_fidelities std_fidelities max_fidelities min_fidelities mean_times mean_costs mean_sc_robust std_sc_robust mean_width_robust std_width_robust

println("Saved all trajectory data to: $(data_file)")

# Optional: Also save a human-readable summary
summary_file = joinpath(data_dir, "summary.txt")
open(summary_file, "w") do io
    println(io, "Multi-Seed Trajectory Analysis Summary")
    println(io, "="^60)
    println(io, "\nParameter Ranges:")
    println(io, "  a_bounds: $(a_bounds)")
    println(io, "  dda_bounds: $(dda_bounds)")
    println(io, "  Number of seeds: $(n_seeds)")
    println(io, "  Seed values: $(seed_values)")
    println(io, "\nFidelity Statistics:")
    println(io, "  Mean of means: $(Printf.@sprintf("%.6f", mean(mean_fidelities)))")
    println(io, "  Mean of stds: $(Printf.@sprintf("%.6f", mean(std_fidelities)))")
    println(io, "  Max std: $(Printf.@sprintf("%.6f", maximum(std_fidelities)))")
    println(io, "  Overall best: $(Printf.@sprintf("%.6f", maximum(fidelities)))")
    println(io, "  Overall worst: $(Printf.@sprintf("%.6f", minimum(fidelities)))")
    println(io, "\nSpace Curve Robustness:")
    println(io, "  Mean across all: $(Printf.@sprintf("%.4f", mean(mean_sc_robust)))")
    println(io, "  Std across params: $(Printf.@sprintf("%.4f", std(mean_sc_robust)))")
    println(io, "  Avg std across seeds: $(Printf.@sprintf("%.4f", mean(std_sc_robust)))")
    println(io, "\nWidth Robustness:")
    println(io, "  Mean across all: $(Printf.@sprintf("%.4f", mean(mean_width_robust)))")
    println(io, "  Std across params: $(Printf.@sprintf("%.4f", std(mean_width_robust)))")
    println(io, "  Avg std across seeds: $(Printf.@sprintf("%.4f", mean(std_width_robust)))")
end

println("Saved summary to: $(summary_file)")
# Out:
# Saved all trajectory data to: /Users/samafine1/Documents/research/pulses/project/notebooks/src/plots/a_dda_landscape/trajectory_data.jld2
# Saved summary to: /Users/samafine1/Documents/research/pulses/project/notebooks/src/plots/a_dda_landscape/summary.txt
