# %% [markdown]
# # Robustness Analysis: Adjoint and Toggle-Frame Objectives Subject to Either Multiplicative or Additive Errors
#
# This notebook compares the performance of the adjoint and Universal robustness objectives for multiplicative and additive error terms in the system's Hamiltonian.

# %% [markdown]
# ## Imports

# %%
import Pkg; Pkg.activate(@__DIR__); Pkg.instantiate();
using PiccoloQuantumObjects
using QuantumCollocation
using ForwardDiff
using LinearAlgebra
using Plots
using SparseArrays
using NamedTrajectories
using Statistics
using CairoMakie
using Random
using ColorSchemes
using Makie
using Printf
# Out:
#   Activating project at `~/Documents/research/pulses/project/notebooks/src`
# ┌ Warning: Circular dependency detected.
# │ Precompilation will be skipped for dependencies in this cycle:
# │  ┌ Piccolissimo
# │  └─ QuantumCollocation
# └ @ Base.Precompilation precompilation.jl:651

# %%
# Problem parameters
T = 20
Δt = 0.2
U_goal = GATES.H
H_drive = [PAULIS.X, PAULIS.Y, PAULIS.Z]
piccolo_opts = PiccoloOptions(verbose=false)
pretty_print(X::AbstractMatrix) = Base.show(stdout, "text/plain", X);
sys = QuantumSystem(H_drive)
# Adjoint
∂ₑHₐ = [PAULIS.X, PAULIS.Y, PAULIS.Z]
varsys = VariationalQuantumSystem(
    H_drive,
    ∂ₑHₐ
)
# Out:
# VariationalQuantumSystem: levels = 2, n_drives = 3

# %% [markdown]
# Setup metrics

# %%
function SpaceCurve(traj::NamedTrajectory, U_goal::AbstractMatrix{<:Number}, H_err::AbstractMatrix{<:Number})
    T = traj.T
    first_order_terms = Vector{Matrix{ComplexF64}}(undef, T)
    first_order_integral = zeros(ComplexF64, size(U_goal))

    for i in 1:T
        U = iso_vec_to_operator(traj.Ũ⃗[:, i])
        first_order_integral += U' * H_err * U
        first_order_terms[i] = first_order_integral
    end
    d = size(U_goal)[1]
    space_curve = [[real(tr(PAULIS.X * first_order_terms[t] / (d * T))),
                    real(tr(PAULIS.Y * first_order_terms[t] / (d * T))),
                    real(tr(PAULIS.Z * first_order_terms[t] / (d * T)))] for t in 1:T] 
    return space_curve
end

function space_curve_robustness(traj::NamedTrajectory, U_goal::AbstractMatrix, H_err::AbstractMatrix)
    curve = SpaceCurve(traj, U_goal, H_err)
    # Use the norm of the final point as a robustness measure
    # (larger values indicate more accumulated error sensitivity)
    final_point = curve[end]
    return norm(final_point)
end

function width_robustness(system::AbstractQuantumSystem, traj::NamedTrajectory; thresh::Float64=0.999)
    F = 1.0
    drift = system.H.H_drift
    drive = system.H.H_drives
    pauls = [PAULIS.X, PAULIS.Y, PAULIS.Z]
    widths = []
    for i in 1:3
        ε = 0.0
        err = pauls[i]
        F = 1.0
        while (ε < 0.5 && F >= thresh)
            noisy_drift = drift + ε * err
            noisy_sys = QuantumSystem(noisy_drift, drive)
            F = unitary_rollout_fidelity(traj, noisy_sys)
            ε += 0.0001
        end
        push!(widths, ε)
    end
    return widths
end
# Out:
# width_robustness (generic function with 1 method)

# %%
# Define parameter ranges (logarithmic scale)
a_bounds = 10 .^ range(-1, 1, length=12)  # 1e-1 to 1e1
dda_bounds = 10 .^ range(-1, 1, length=12)  # 1e-1 to 1e1

n_seeds = 2  # Number of random seeds to test

println("Parameter ranges:")
println("a_bounds: ", a_bounds)
println("dda_bounds: ", dda_bounds)
println("Number of seeds: ", n_seeds)

# Initialize results storage - now with an extra dimension for seeds
trajectories = Array{Any}(undef, length(a_bounds), length(dda_bounds), n_seeds)
fidelities = zeros(length(a_bounds), length(dda_bounds), n_seeds)
convergence_times = zeros(length(a_bounds), length(dda_bounds), n_seeds)
final_costs = zeros(length(a_bounds), length(dda_bounds), n_seeds)

# Define error Hamiltonian function
H_ϵ_add = a -> [PAULIS.X, PAULIS.Y, PAULIS.Z]

# Define seeds to use consistently across all parameter combinations
seed_values = [42, 123]  # Same seeds as adjoint notebook for fair comparison

# Parameter sweep
println("\nStarting parameter sweep with multiple seeds...")
for (i, a_bound) in enumerate(a_bounds)
    for (j, dda_bound) in enumerate(dda_bounds)
        println("\n" * "="^60)
        println("Parameter set: a_bound=$(Printf.@sprintf("%.3e", a_bound)), dda_bound=$(Printf.@sprintf("%.3e", dda_bound))")
        println("="^60)
        
        for (seed_idx, seed) in enumerate(seed_values)
            println("\n  Seed $seed_idx (value=$seed):")
            
            # Set random seed for reproducibility
            Random.seed!(seed)
            
            uni_prob_test = UnitaryUniversalProblem(
                sys, U_goal, T, Δt;
                a_bound = a_bound,
                dda_bound = dda_bound,
                activate_hyperspeed=true,
                piccolo_options=piccolo_opts,
            )
            
            # Solve with timing
            elapsed_time = @elapsed begin
                solve!(uni_prob_test, max_iter=500, print_level=0, 
                        options=IpoptOptions(eval_hessian=false))
                solve!(uni_prob_test, max_iter=25, print_level=0)
            end
            
            # Calculate final fidelity
            fidelity = unitary_rollout_fidelity(uni_prob_test.trajectory, sys)
            
            # Store results
            trajectories[i, j, seed_idx] = uni_prob_test.trajectory
            fidelities[i, j, seed_idx] = fidelity
            convergence_times[i, j, seed_idx] = elapsed_time
            Z_vec = vec(uni_prob_test.trajectory)
            final_costs[i, j, seed_idx] = uni_prob_test.objective.L(Z_vec)
            
            println("    -> Fidelity: $(Printf.@sprintf("%.6f", fidelity)), Time: $(Printf.@sprintf("%.2f", elapsed_time))s, Cost: $(Printf.@sprintf("%.4e", final_costs[i, j, seed_idx]))")
        end
        
        # Compare seeds for this parameter combination
        fid_diff = abs(fidelities[i, j, 1] - fidelities[i, j, 2])
        println("\n  Seed comparison:")
        println("    Fidelity difference: $(Printf.@sprintf("%.6f", fid_diff))")
        println("    Best seed: $(fidelities[i, j, 1] >= fidelities[i, j, 2] ? "Seed 1" : "Seed 2")")
    end
end

# Compute statistics across seeds
mean_fidelities = mean(fidelities, dims=3)[:, :, 1]
std_fidelities = std(fidelities, dims=3)[:, :, 1]
max_fidelities = maximum(fidelities, dims=3)[:, :, 1]
min_fidelities = minimum(fidelities, dims=3)[:, :, 1]

mean_times = mean(convergence_times, dims=3)[:, :, 1]
mean_costs = mean(final_costs, dims=3)[:, :, 1]

println("\n" * "="^80)
println("MULTI-SEED ANALYSIS COMPLETE (UNIVERSAL)")
println("="^80)
println("\nFidelity statistics across seeds:")
println("  Mean of means: $(Printf.@sprintf("%.6f", mean(mean_fidelities)))")
println("  Mean of stds: $(Printf.@sprintf("%.6f", mean(std_fidelities)))")
println("  Max std: $(Printf.@sprintf("%.6f", maximum(std_fidelities)))")
println("  Overall best: $(Printf.@sprintf("%.6f", maximum(fidelities)))")
println("  Overall worst: $(Printf.@sprintf("%.6f", minimum(fidelities)))")
# Out:
# Parameter ranges:
# a_bounds: [0.1, 0.15199110829529336, 0.23101297000831597, 0.35111917342151316, 0.533669923120631, 0.8111308307896871, 1.2328467394420661, 1.8738174228603839, 2.8480358684358014, 4.328761281083058, 6.579332246575681, 10.0]
# dda_bounds: [0.1, 0.15199110829529336, 0.23101297000831597, 0.35111917342151316, 0.533669923120631, 0.8111308307896871, 1.2328467394420661, 1.8738174228603839, 2.8480358684358014, 4.328761281083058, 6.579332246575681, 10.0]
# Number of seeds: 2
#
# Starting parameter sweep with multiple seeds...
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.000e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.651233, Time: 77.06s, Cost: 3.5056e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.651233, Time: 30.28s, Cost: 3.5056e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.520e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.671190, Time: 30.95s, Cost: 3.3056e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.671191, Time: 31.40s, Cost: 3.3056e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=2.310e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.692049, Time: 35.31s, Cost: 3.0966e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.692060, Time: 31.85s, Cost: 3.0965e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000011
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=3.511e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.702040, Time: 33.96s, Cost: 2.9966e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.702095, Time: 29.73s, Cost: 2.9960e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000055
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=5.337e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.717039, Time: 32.66s, Cost: 2.8464e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.717095, Time: 32.50s, Cost: 2.8459e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000056
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=8.111e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 30.07s, Cost: 2.7722e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724511, Time: 34.28s, Cost: 2.7716e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000056
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.233e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 30.82s, Cost: 2.7722e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 32.86s, Cost: 2.7722e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.874e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724467, Time: 33.46s, Cost: 2.7721e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 31.48s, Cost: 2.7722e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000011
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=2.848e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 31.41s, Cost: 2.7722e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 30.34s, Cost: 2.7722e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=4.329e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 31.04s, Cost: 2.7722e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724456, Time: 31.91s, Cost: 2.7722e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=6.579e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724511, Time: 31.12s, Cost: 2.7716e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724511, Time: 30.86s, Cost: 2.7716e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e-01, dda_bound=1.000e+01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724511, Time: 33.30s, Cost: 2.7716e+01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.724511, Time: 30.54s, Cost: 2.7716e+01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.000e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.964071, Time: 30.64s, Cost: 3.5701e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.964071, Time: 34.13s, Cost: 3.5701e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.520e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.979536, Time: 34.17s, Cost: 2.0139e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.979492, Time: 32.49s, Cost: 2.0183e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000044
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=2.310e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.987576, Time: 32.24s, Cost: 1.2045e+00
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.987576, Time: 30.78s, Cost: 1.2046e+00
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=3.511e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.993982, Time: 32.70s, Cost: 5.5890e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.993971, Time: 34.55s, Cost: 5.6003e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000011
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=5.337e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.996259, Time: 32.35s, Cost: 3.2966e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.996248, Time: 31.65s, Cost: 3.3076e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000011
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=8.111e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.998681, Time: 31.83s, Cost: 8.5607e-02
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.998681, Time: 32.19s, Cost: 8.5599e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.233e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999412, Time: 33.96s, Cost: 1.1981e-02
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999410, Time: 42.26s, Cost: 1.2135e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000002
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.874e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999412, Time: 33.41s, Cost: 1.1981e-02
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999422, Time: 33.94s, Cost: 1.0907e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000010
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=2.848e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999461, Time: 32.19s, Cost: 6.6450e-03
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999461, Time: 33.48s, Cost: 6.6450e-03
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=4.329e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999422, Time: 33.79s, Cost: 1.0907e-02
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999422, Time: 32.48s, Cost: 1.0924e-02
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=6.579e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999422, Time: 32.09s, Cost: 1.0907e-02
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999461, Time: 32.34s, Cost: 6.6480e-03
#
#   Seed comparison:
#     Fidelity difference: 0.000039
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.520e-01, dda_bound=1.000e+01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
# ...
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 15.10s, Cost: -2.5063e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 15.47s, Cost: -5.9005e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=8.111e-01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999995, Time: 15.03s, Cost: -5.8357e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999999, Time: 15.00s, Cost: -6.1351e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000003
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=1.233e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 14.96s, Cost: -6.1357e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 15.05s, Cost: -6.1391e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 1
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=1.874e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 16.24s, Cost: -5.7580e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 16.10s, Cost: -6.0970e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000000
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=2.848e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999976, Time: 16.00s, Cost: -5.7576e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 15.44s, Cost: -6.1344e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000024
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=4.329e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999990, Time: 15.42s, Cost: -4.1470e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999999, Time: 14.93s, Cost: -6.1027e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000009
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=6.579e+00
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.999983, Time: 15.80s, Cost: -4.8269e-01
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 15.80s, Cost: -6.1137e-01
#
#   Seed comparison:
#     Fidelity difference: 0.000017
#     Best seed: Seed 2
#
# ============================================================
# Parameter set: a_bound=1.000e+01, dda_bound=1.000e+01
# ============================================================
#
#   Seed 1 (value=42):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 0.990667, Time: 15.11s, Cost: 2.9090e-02
#
#   Seed 2 (value=123):
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     initializing optimizer...
#         applying constraint: timesteps all equal constraint
#         applying constraint: initial value of Ũ⃗
#         applying constraint: initial value of a
#         applying constraint: final value of a
#         applying constraint: bounds on a
#         applying constraint: bounds on da
#         applying constraint: bounds on dda
#         applying constraint: bounds on Δt
#     -> Fidelity: 1.000000, Time: 14.85s, Cost: -4.8796e-01
#
#   Seed comparison:
#     Fidelity difference: 0.009333
#     Best seed: Seed 2
#
# ================================================================================
# MULTI-SEED ANALYSIS COMPLETE (UNIVERSAL)
# ================================================================================
#
# Fidelity statistics across seeds:
#   Mean of means: 0.975075
#   Mean of stds: 0.000102
#   Max std: 0.006600
#   Overall best: 1.000000
#   Overall worst: 0.651233

# %%
# Create comprehensive visualization with multi-seed analysis for Universal
f = Figure(size=(1800, 1200))

# 1. Mean Fidelity 3D Surface Plot
ax3d = Axis3(f[1, 1:2],
    title="Mean Fidelity Across Seeds vs a_bound and dda_bound (Universal)",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)",
    zlabel="Mean Fidelity",
    aspect=(1, 1, 0.5)
)

# Create meshgrid for 3D plot
x_3d = repeat(log10.(a_bounds), 1, length(dda_bounds))
y_3d = repeat(log10.(dda_bounds)', length(a_bounds), 1)
z_3d = mean_fidelities

# Create 3D surface
Makie.surface!(ax3d, x_3d, y_3d, z_3d, colormap=:viridis, alpha=0.8)
Makie.contour3d!(ax3d, x_3d, y_3d, z_3d, levels=10, linewidth=1, alpha=0.6)

# 2. Mean Fidelity 2D Heatmap
ax_heat_mean = Axis(f[2, 1],
    title="Mean Fidelity Heatmap",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)

hm_mean = Makie.heatmap!(ax_heat_mean, log10.(a_bounds), log10.(dda_bounds), mean_fidelities,
             colormap=:viridis, colorrange=(0.95, 1.0))
Colorbar(f[2, 2], hm_mean, label="Mean Fidelity")

Makie.contour!(ax_heat_mean, log10.(a_bounds), log10.(dda_bounds), mean_fidelities,
        levels=[0.99, 0.995, 0.999], color=:white, linewidth=1.5)

# 3. Standard Deviation Heatmap (shows seed variability)
ax_heat_std = Axis(f[1, 3],
    title="Fidelity Std Dev Across Seeds",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)

hm_std = Makie.heatmap!(ax_heat_std, log10.(a_bounds), log10.(dda_bounds), std_fidelities,
             colormap=:reds)
Colorbar(f[1, 4], hm_std, label="Std Dev")

# 4. Max-Min Difference (shows range across seeds)
fidelity_range = max_fidelities - min_fidelities
ax_heat_range = Axis(f[2, 3],
    title="Fidelity Range Across Seeds",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)

hm_range = Makie.heatmap!(ax_heat_range, log10.(a_bounds), log10.(dda_bounds), fidelity_range,
             colormap=:plasma)
Colorbar(f[2, 4], hm_range, label="Max - Min")

# 5. Cross-section comparison showing variability
ax_cross1 = Axis(f[3, 1:2],
    title="Mean Fidelity vs a_bound with Std Dev Bands",
    xlabel="log₁₀(a_bound)",
    ylabel="Fidelity"
)

# Select middle dda_bound for cross-section
mid_dda_idx = round(Int, length(dda_bounds)/2)

# Plot mean with error bands
lines!(ax_cross1, log10.(a_bounds), mean_fidelities[:, mid_dda_idx],
       label="Mean", color=:blue, linewidth=3)
band!(ax_cross1, log10.(a_bounds),
      mean_fidelities[:, mid_dda_idx] .- std_fidelities[:, mid_dda_idx],
      mean_fidelities[:, mid_dda_idx] .+ std_fidelities[:, mid_dda_idx],
      color=(:blue, 0.3), label="±1 Std Dev")

# Plot individual seeds
for seed_idx in 1:n_seeds
    lines!(ax_cross1, log10.(a_bounds), fidelities[:, mid_dda_idx, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash)
end

axislegend(ax_cross1, position=:rb)

# 6. Cross-section for dda_bound
ax_cross2 = Axis(f[3, 3:4],
    title="Mean Fidelity vs dda_bound with Std Dev Bands",
    xlabel="log₁₀(dda_bound)",
    ylabel="Fidelity"
)

# Select middle a_bound for cross-section
mid_a_idx = round(Int, length(a_bounds)/2)

lines!(ax_cross2, log10.(dda_bounds), mean_fidelities[mid_a_idx, :],
       label="Mean", color=:red, linewidth=3)
band!(ax_cross2, log10.(dda_bounds),
      mean_fidelities[mid_a_idx, :] .- std_fidelities[mid_a_idx, :],
      mean_fidelities[mid_a_idx, :] .+ std_fidelities[mid_a_idx, :],
      color=(:red, 0.3), label="±1 Std Dev")

# Plot individual seeds
for seed_idx in 1:n_seeds
    lines!(ax_cross2, log10.(dda_bounds), fidelities[mid_a_idx, :, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash)
end

axislegend(ax_cross2, position=:rb)

# Add overall title
Label(f[0, 1:4], "Multi-Seed Universal Quantum Control: Parameter Sensitivity Analysis",
      fontsize=20, font="bold")

# Display the figure
display(f)

# Print summary statistics
println("\n" * "="^60)
println("SUMMARY STATISTICS (MULTI-SEED - Universal)")
println("="^60)

max_mean_fidelity = maximum(mean_fidelities)
max_idx = argmax(mean_fidelities)
best_a = a_bounds[max_idx[1]]
best_dda = dda_bounds[max_idx[2]]

println("\nBest mean fidelity: $(Printf.@sprintf("%.6f", max_mean_fidelity))")
println("Best parameters: a_bound = $(Printf.@sprintf("%.3e", best_a)), dda_bound = $(Printf.@sprintf("%.3e", best_dda))")
println("Std dev at best params: $(Printf.@sprintf("%.6f", std_fidelities[max_idx]))")
println("Range at best params: $(Printf.@sprintf("%.6f", fidelity_range[max_idx]))")

# Find parameters with both high mean and low variance
high_quality_mask = (mean_fidelities .> 0.999) .& (std_fidelities .< 0.001)
n_high_quality = sum(high_quality_mask)
println("\nParameter combinations with fidelity > 0.999 AND std < 0.001: $n_high_quality / $(length(mean_fidelities))")

# Identify most stable parameter regions (low variance)
min_std = minimum(std_fidelities)
min_std_idx = argmin(std_fidelities)
println("\nMost stable parameters (lowest std dev):")
println("  a_bound = $(Printf.@sprintf("%.3e", a_bounds[min_std_idx[1]])), dda_bound = $(Printf.@sprintf("%.3e", dda_bounds[min_std_idx[2]]))")
println("  Std dev: $(Printf.@sprintf("%.6f", min_std))")
println("  Mean fidelity: $(Printf.@sprintf("%.6f", mean_fidelities[min_std_idx]))")

# Seed sensitivity analysis
avg_std = mean(std_fidelities)
max_std = maximum(std_fidelities)
max_std_idx = argmax(std_fidelities)
println("\nSeed sensitivity across all parameters:")
println("  Average std dev: $(Printf.@sprintf("%.6f", avg_std))")
println("  Maximum std dev: $(Printf.@sprintf("%.6f", max_std))")
println("  Most sensitive at: a_bound = $(Printf.@sprintf("%.3e", a_bounds[max_std_idx[1]])), dda_bound = $(Printf.@sprintf("%.3e", dda_bounds[max_std_idx[2]]))")
# Out:
# ============================================================
# SUMMARY STATISTICS (MULTI-SEED - Universal)
# ============================================================
#
# Best mean fidelity: 1.000000
# Best parameters: a_bound = 8.111e-01, dda_bound = 1.874e+00
# Std dev at best params: 0.000000
# Range at best params: 0.000000
#
# Parameter combinations with fidelity > 0.999 AND std < 0.001: 122 / 144
#
# Most stable parameters (lowest std dev):
#   a_bound = 1.000e-01, dda_bound = 1.000e-01
#   Std dev: 0.000000
#   Mean fidelity: 0.651233
#
# Seed sensitivity across all parameters:
#   Average std dev: 0.000102
#   Maximum std dev: 0.006600
#   Most sensitive at: a_bound = 1.000e+01, dda_bound = 1.000e+01

# %%
# Calculate robustness metrics for all trajectories (all seeds) - Universal
println("\nCalculating robustness metrics for all seeds (Universal)...")

# Initialize storage for robustness metrics (now with seed dimension)
space_curve_robustness_values = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_x = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_y = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_z = zeros(length(a_bounds), length(dda_bounds), n_seeds)
width_robustness_avg = zeros(length(a_bounds), length(dda_bounds), n_seeds)

# Calculate robustness for each trajectory
for (i, a_bound) in enumerate(a_bounds)
    for (j, dda_bound) in enumerate(dda_bounds)
        for seed_idx in 1:n_seeds
            if !isnothing(trajectories[i, j, seed_idx])
                traj = trajectories[i, j, seed_idx]
                
                # Space curve robustness (average over all Pauli errors)
                Xerr = space_curve_robustness(traj, U_goal, PAULIS.X)
                Yerr = space_curve_robustness(traj, U_goal, PAULIS.Y)
                Zerr = space_curve_robustness(traj, U_goal, PAULIS.Z)
                space_curve_robustness_values[i, j, seed_idx] = 1-(Xerr + Yerr + Zerr) / 3
                
                # Width robustness
                widths = width_robustness(sys, traj, thresh=0.99)
                width_robustness_x[i, j, seed_idx] = widths[1]
                width_robustness_y[i, j, seed_idx] = widths[2]
                width_robustness_z[i, j, seed_idx] = widths[3]
                width_robustness_avg[i, j, seed_idx] = mean(widths)
                
                println("a=$(Printf.@sprintf("%.3e", a_bound)), dda=$(Printf.@sprintf("%.3e", dda_bound)), seed=$seed_idx: " *
                       "SC_robust=$(Printf.@sprintf("%.4f", space_curve_robustness_values[i, j, seed_idx])), " *
                       "Width_avg=$(Printf.@sprintf("%.4f", width_robustness_avg[i, j, seed_idx]))")
            end
        end
    end
end

# Compute statistics across seeds for robustness metrics
mean_sc_robust = mean(space_curve_robustness_values, dims=3)[:, :, 1]
std_sc_robust = std(space_curve_robustness_values, dims=3)[:, :, 1]
mean_width_robust = mean(width_robustness_avg, dims=3)[:, :, 1]
std_width_robust = std(width_robustness_avg, dims=3)[:, :, 1]

# Create comprehensive robustness visualization
f_robust = Figure(size=(2000, 1600))

# Row 1: Mean Space Curve Robustness
ax_sc_3d = Axis3(f_robust[1, 1:2],
    title="Mean Space Curve Robustness (Universal)",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)",
    zlabel="SC Robustness",
    aspect=(1, 1, 0.5)
)

x_3d = repeat(log10.(a_bounds), 1, length(dda_bounds))
y_3d = repeat(log10.(dda_bounds)', length(a_bounds), 1)
Makie.surface!(ax_sc_3d, x_3d, y_3d, mean_sc_robust, colormap=:plasma, alpha=0.8)
Makie.contour3d!(ax_sc_3d, x_3d, y_3d, mean_sc_robust, levels=10, linewidth=1, alpha=0.6)

ax_sc_heat = Axis(f_robust[1, 3],
    title="Mean SC Robustness",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_sc = Makie.heatmap!(ax_sc_heat, log10.(a_bounds), log10.(dda_bounds), mean_sc_robust, colormap=:plasma)
Colorbar(f_robust[1, 4], hm_sc, label="Mean SC Robust")

ax_sc_std = Axis(f_robust[1, 5],
    title="SC Robustness Std Dev",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_sc_std = Makie.heatmap!(ax_sc_std, log10.(a_bounds), log10.(dda_bounds), std_sc_robust, colormap=:reds)
Colorbar(f_robust[1, 6], hm_sc_std, label="Std Dev")

# Row 2: Mean Width Robustness
ax_w_3d = Axis3(f_robust[2, 1:2],
    title="Mean Width Robustness (Universal)",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)",
    zlabel="Width Robustness",
    aspect=(1, 1, 0.5)
)

Makie.surface!(ax_w_3d, x_3d, y_3d, mean_width_robust, colormap=:turbo, alpha=0.8)
Makie.contour3d!(ax_w_3d, x_3d, y_3d, mean_width_robust, levels=10, linewidth=1, alpha=0.6)

ax_w_heat = Axis(f_robust[2, 3],
    title="Mean Width Robustness",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_w = Makie.heatmap!(ax_w_heat, log10.(a_bounds), log10.(dda_bounds), mean_width_robust, colormap=:turbo)
Colorbar(f_robust[2, 4], hm_w, label="Mean Width")

ax_w_std = Axis(f_robust[2, 5],
    title="Width Robustness Std Dev",
    xlabel="log₁₀(a_bound)",
    ylabel="log₁₀(dda_bound)"
)
hm_w_std = Makie.heatmap!(ax_w_std, log10.(a_bounds), log10.(dda_bounds), std_width_robust, colormap=:reds)
Colorbar(f_robust[2, 6], hm_w_std, label="Std Dev")

# Row 3: Correlation analysis
ax_corr = Axis(f_robust[3, 1:3],
    title="Correlation: Space Curve vs Width Robustness (All Seeds)",
    xlabel="Space Curve Robustness",
    ylabel="Width Robustness"
)

# Flatten all seeds for correlation plot
sc_all = vec(space_curve_robustness_values)
w_all = vec(width_robustness_avg)
fid_all = vec(fidelities)

# Create scatter with seed coloring
colors_seeds = [:red, :blue, :green, :orange, :purple]
for seed_idx in 1:n_seeds
    sc_seed = vec(space_curve_robustness_values[:, :, seed_idx])
    w_seed = vec(width_robustness_avg[:, :, seed_idx])
    Makie.scatter!(ax_corr, sc_seed, w_seed,
              label="Seed $seed_idx",
              color=colors_seeds[seed_idx],
              markersize=6, alpha=0.6)
end

correlation = cor(sc_all, w_all)
text!(ax_corr, 0.05, 0.95, text="Overall Correlation: $(Printf.@sprintf("%.3f", correlation))",
      space=:relative, fontsize=14, font="bold")
axislegend(ax_corr, position=:rb)

# Row 3: Summary statistics
ax_summary = Axis(f_robust[3, 4:6],
    title="Multi-Seed Robustness Summary"
)
hidedecorations!(ax_summary)
hidespines!(ax_summary)

summary_text = """
Space Curve Robustness:
  Mean across all: $(Printf.@sprintf("%.4f", mean(mean_sc_robust)))
  Std across params: $(Printf.@sprintf("%.4f", std(mean_sc_robust)))
  Avg std across seeds: $(Printf.@sprintf("%.4f", mean(std_sc_robust)))
  Min mean: $(Printf.@sprintf("%.4f", minimum(mean_sc_robust)))
  Max mean: $(Printf.@sprintf("%.4f", maximum(mean_sc_robust)))

Width Robustness:
  Mean across all: $(Printf.@sprintf("%.4f", mean(mean_width_robust)))
  Std across params: $(Printf.@sprintf("%.4f", std(mean_width_robust)))
  Avg std across seeds: $(Printf.@sprintf("%.4f", mean(std_width_robust)))
  Min mean: $(Printf.@sprintf("%.4f", minimum(mean_width_robust)))
  Max mean: $(Printf.@sprintf("%.4f", maximum(mean_width_robust)))

Seed Variability:
  Params with high SC std (>0.01): $(sum(std_sc_robust .> 0.01))
  Params with high W std (>0.01): $(sum(std_width_robust .> 0.01))

Best Combined (Fidelity + Robustness):
  Using mean fidelity > 0.999 & mean width > 0.1
  Count: $(sum((mean_fidelities .> 0.999) .& (mean_width_robust .> 0.1)))
"""

text!(ax_summary, 0.05, 0.5, text=summary_text,
      space=:relative, fontsize=11, font="monospace")

# Row 4: Cross-sections with seed bands
mid_dda = round(Int, length(dda_bounds)/2)
mid_a = round(Int, length(a_bounds)/2)

ax_cross_sc = Axis(f_robust[4, 1:3],
    title="Space Curve Robustness vs a_bound (with seed variability)",
    xlabel="log₁₀(a_bound)",
    ylabel="SC Robustness"
)

lines!(ax_cross_sc, log10.(a_bounds), mean_sc_robust[:, mid_dda],
       label="Mean", color=:blue, linewidth=3)
band!(ax_cross_sc, log10.(a_bounds),
      mean_sc_robust[:, mid_dda] .- std_sc_robust[:, mid_dda],
      mean_sc_robust[:, mid_dda] .+ std_sc_robust[:, mid_dda],
      color=(:blue, 0.3), label="±1 Std")

for seed_idx in 1:n_seeds
    lines!(ax_cross_sc, log10.(a_bounds), space_curve_robustness_values[:, mid_dda, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash, color=colors_seeds[seed_idx])
end
axislegend(ax_cross_sc, position=:rt)

ax_cross_w = Axis(f_robust[4, 4:6],
    title="Width Robustness vs dda_bound (with seed variability)",
    xlabel="log₁₀(dda_bound)",
    ylabel="Width Robustness"
)

lines!(ax_cross_w, log10.(dda_bounds), mean_width_robust[mid_a, :],
       label="Mean", color=:red, linewidth=3)
band!(ax_cross_w, log10.(dda_bounds),
      mean_width_robust[mid_a, :] .- std_width_robust[mid_a, :],
      mean_width_robust[mid_a, :] .+ std_width_robust[mid_a, :],
      color=(:red, 0.3), label="±1 Std")

for seed_idx in 1:n_seeds
    lines!(ax_cross_w, log10.(dda_bounds), width_robustness_avg[mid_a, :, seed_idx],
           label="Seed $seed_idx", linewidth=1.5, linestyle=:dash, color=colors_seeds[seed_idx])
end
axislegend(ax_cross_w, position=:lt)

Label(f_robust[0, :], "Multi-Seed Robustness Analysis (Universal): Parameter Sensitivity",
      fontsize=20, font="bold")

display(f_robust)

println("\nMulti-seed robustness analysis complete (Universal)!")
# Out:
# Calculating robustness metrics for all seeds (Universal)...
# a=1.000e-01, dda=1.000e-01, seed=1: SC_robust=0.1192, Width_avg=0.0001
# a=1.000e-01, dda=1.000e-01, seed=2: SC_robust=0.1192, Width_avg=0.0001
# a=1.000e-01, dda=1.520e-01, seed=1: SC_robust=0.1214, Width_avg=0.0001
# a=1.000e-01, dda=1.520e-01, seed=2: SC_robust=0.1214, Width_avg=0.0001
# a=1.000e-01, dda=2.310e-01, seed=1: SC_robust=0.1236, Width_avg=0.0001
# a=1.000e-01, dda=2.310e-01, seed=2: SC_robust=0.1236, Width_avg=0.0001
# a=1.000e-01, dda=3.511e-01, seed=1: SC_robust=0.1244, Width_avg=0.0001
# a=1.000e-01, dda=3.511e-01, seed=2: SC_robust=0.1244, Width_avg=0.0001
# a=1.000e-01, dda=5.337e-01, seed=1: SC_robust=0.1257, Width_avg=0.0001
# a=1.000e-01, dda=5.337e-01, seed=2: SC_robust=0.1257, Width_avg=0.0001
# a=1.000e-01, dda=8.111e-01, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=8.111e-01, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.233e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.233e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.874e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.874e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=2.848e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=2.848e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=4.329e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=4.329e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=6.579e+00, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=6.579e+00, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.000e+01, seed=1: SC_robust=0.1264, Width_avg=0.0001
# a=1.000e-01, dda=1.000e+01, seed=2: SC_robust=0.1264, Width_avg=0.0001
# a=1.520e-01, dda=1.000e-01, seed=1: SC_robust=0.2404, Width_avg=0.0001
# a=1.520e-01, dda=1.000e-01, seed=2: SC_robust=0.2404, Width_avg=0.0001
# a=1.520e-01, dda=1.520e-01, seed=1: SC_robust=0.2470, Width_avg=0.0001
# a=1.520e-01, dda=1.520e-01, seed=2: SC_robust=0.2470, Width_avg=0.0001
# a=1.520e-01, dda=2.310e-01, seed=1: SC_robust=0.2507, Width_avg=0.0001
# a=1.520e-01, dda=2.310e-01, seed=2: SC_robust=0.2507, Width_avg=0.0001
# a=1.520e-01, dda=3.511e-01, seed=1: SC_robust=0.2545, Width_avg=0.0218
# a=1.520e-01, dda=3.511e-01, seed=2: SC_robust=0.2545, Width_avg=0.0218
# a=1.520e-01, dda=5.337e-01, seed=1: SC_robust=0.2559, Width_avg=0.0218
# a=1.520e-01, dda=5.337e-01, seed=2: SC_robust=0.2559, Width_avg=0.0218
# a=1.520e-01, dda=8.111e-01, seed=1: SC_robust=0.2580, Width_avg=0.0142
# a=1.520e-01, dda=8.111e-01, seed=2: SC_robust=0.2580, Width_avg=0.0207
# a=1.520e-01, dda=1.233e+00, seed=1: SC_robust=0.2589, Width_avg=0.0199
# a=1.520e-01, dda=1.233e+00, seed=2: SC_robust=0.2589, Width_avg=0.0199
# a=1.520e-01, dda=1.874e+00, seed=1: SC_robust=0.2589, Width_avg=0.0199
# a=1.520e-01, dda=1.874e+00, seed=2: SC_robust=0.2590, Width_avg=0.0199
# a=1.520e-01, dda=2.848e+00, seed=1: SC_robust=0.2592, Width_avg=0.0199
# a=1.520e-01, dda=2.848e+00, seed=2: SC_robust=0.2592, Width_avg=0.0199
# a=1.520e-01, dda=4.329e+00, seed=1: SC_robust=0.2590, Width_avg=0.0199
# a=1.520e-01, dda=4.329e+00, seed=2: SC_robust=0.2590, Width_avg=0.0199
# a=1.520e-01, dda=6.579e+00, seed=1: SC_robust=0.2590, Width_avg=0.0199
# a=1.520e-01, dda=6.579e+00, seed=2: SC_robust=0.2592, Width_avg=0.0199
# a=1.520e-01, dda=1.000e+01, seed=1: SC_robust=0.2590, Width_avg=0.0199
# a=1.520e-01, dda=1.000e+01, seed=2: SC_robust=0.2590, Width_avg=0.0199
# a=2.310e-01, dda=1.000e-01, seed=1: SC_robust=0.3795, Width_avg=0.0211
# a=2.310e-01, dda=1.000e-01, seed=2: SC_robust=0.3795, Width_avg=0.0214
# a=2.310e-01, dda=1.520e-01, seed=1: SC_robust=0.4078, Width_avg=0.0220
# a=2.310e-01, dda=1.520e-01, seed=2: SC_robust=0.4066, Width_avg=0.0219
# a=2.310e-01, dda=2.310e-01, seed=1: SC_robust=0.4190, Width_avg=0.0224
# a=2.310e-01, dda=2.310e-01, seed=2: SC_robust=0.4192, Width_avg=0.0226
# a=2.310e-01, dda=3.511e-01, seed=1: SC_robust=0.4265, Width_avg=0.0227
# a=2.310e-01, dda=3.511e-01, seed=2: SC_robust=0.4265, Width_avg=0.0229
# a=2.310e-01, dda=5.337e-01, seed=1: SC_robust=0.4371, Width_avg=0.0233
# a=2.310e-01, dda=5.337e-01, seed=2: SC_robust=0.4355, Width_avg=0.0233
# a=2.310e-01, dda=8.111e-01, seed=1: SC_robust=0.3891, Width_avg=0.0220
# a=2.310e-01, dda=8.111e-01, seed=2: SC_robust=0.4391, Width_avg=0.0232
# a=2.310e-01, dda=1.233e+00, seed=1: SC_robust=0.4436, Width_avg=0.0240
# a=2.310e-01, dda=1.233e+00, seed=2: SC_robust=0.4425, Width_avg=0.0237
# a=2.310e-01, dda=1.874e+00, seed=1: SC_robust=0.4449, Width_avg=0.0238
# a=2.310e-01, dda=1.874e+00, seed=2: SC_robust=0.4436, Width_avg=0.0235
# a=2.310e-01, dda=2.848e+00, seed=1: SC_robust=0.4450, Width_avg=0.0234
# a=2.310e-01, dda=2.848e+00, seed=2: SC_robust=0.4280, Width_avg=0.0232
# a=2.310e-01, dda=4.329e+00, seed=1: SC_robust=0.4390, Width_avg=0.0235
# a=2.310e-01, dda=4.329e+00, seed=2: SC_robust=0.2924, Width_avg=0.0224
# a=2.310e-01, dda=6.579e+00, seed=1: SC_robust=0.4447, Width_avg=0.0238
# a=2.310e-01, dda=6.579e+00, seed=2: SC_robust=0.4067, Width_avg=0.0232
# a=2.310e-01, dda=1.000e+01, seed=1: SC_robust=0.4273, Width_avg=0.0228
# a=2.310e-01, dda=1.000e+01, seed=2: SC_robust=0.4078, Width_avg=0.0227
# a=3.511e-01, dda=1.000e-01, seed=1: SC_robust=0.4543, Width_avg=0.0244
# a=3.511e-01, dda=1.000e-01, seed=2: SC_robust=0.4543, Width_avg=0.0244
# a=3.511e-01, dda=1.520e-01, seed=1: SC_robust=0.5279, Width_avg=0.0268
# a=3.511e-01, dda=1.520e-01, seed=2: SC_robust=0.5278, Width_avg=0.0268
# a=3.511e-01, dda=2.310e-01, seed=1: SC_robust=0.5304, Width_avg=0.0274
# a=3.511e-01, dda=2.310e-01, seed=2: SC_robust=0.5319, Width_avg=0.0274
# a=3.511e-01, dda=3.511e-01, seed=1: SC_robust=0.5781, Width_avg=0.0316
# a=3.511e-01, dda=3.511e-01, seed=2: SC_robust=0.5582, Width_avg=0.0287
# a=3.511e-01, dda=5.337e-01, seed=1: SC_robust=0.6091, Width_avg=0.0334
# a=3.511e-01, dda=5.337e-01, seed=2: SC_robust=0.6092, Width_avg=0.0330
# a=3.511e-01, dda=8.111e-01, seed=1: SC_robust=0.6390, Width_avg=0.0364
# a=3.511e-01, dda=8.111e-01, seed=2: SC_robust=0.6415, Width_avg=0.0367
# a=3.511e-01, dda=1.233e+00, seed=1: SC_robust=0.6307, Width_avg=0.0347
# a=3.511e-01, dda=1.233e+00, seed=2: SC_robust=0.6326, Width_avg=0.0343
# a=3.511e-01, dda=1.874e+00, seed=1: SC_robust=0.6498, Width_avg=0.0389
# a=3.511e-01, dda=1.874e+00, seed=2: SC_robust=0.6378, Width_avg=0.0350
# a=3.511e-01, dda=2.848e+00, seed=1: SC_robust=0.6489, Width_avg=0.0363
# a=3.511e-01, dda=2.848e+00, seed=2: SC_robust=0.5175, Width_avg=0.0289
# a=3.511e-01, dda=4.329e+00, seed=1: SC_robust=0.6193, Width_avg=0.0335
# a=3.511e-01, dda=4.329e+00, seed=2: SC_robust=0.6308, Width_avg=0.0339
# a=3.511e-01, dda=6.579e+00, seed=1: SC_robust=0.6488, Width_avg=0.0377
# a=3.511e-01, dda=6.579e+00, seed=2: SC_robust=0.6460, Width_avg=0.0375
# a=3.511e-01, dda=1.000e+01, seed=1: SC_robust=0.6453, Width_avg=0.0374
# a=3.511e-01, dda=1.000e+01, seed=2: SC_robust=0.6424, Width_avg=0.0379
# a=5.337e-01, dda=1.000e-01, seed=1: SC_robust=0.4540, Width_avg=0.0239
# a=5.337e-01, dda=1.000e-01, seed=2: SC_robust=0.4672, Width_avg=0.0255
# a=5.337e-01, dda=1.520e-01, seed=1: SC_robust=0.6523, Width_avg=0.0870
# a=5.337e-01, dda=1.520e-01, seed=2: SC_robust=0.6303, Width_avg=0.0444
# a=5.337e-01, dda=2.310e-01, seed=1: SC_robust=0.6365, Width_avg=0.0424
# a=5.337e-01, dda=2.310e-01, seed=2: SC_robust=0.6714, Width_avg=0.0407
# a=5.337e-01, dda=3.511e-01, seed=1: SC_robust=0.6944, Width_avg=0.0539
# a=5.337e-01, dda=3.511e-01, seed=2: SC_robust=0.6970, Width_avg=0.0548
# a=5.337e-01, dda=5.337e-01, seed=1: SC_robust=0.7834, Width_avg=0.0560
# a=5.337e-01, dda=5.337e-01, seed=2: SC_robust=0.7794, Width_avg=0.0539
# a=5.337e-01, dda=8.111e-01, seed=1: SC_robust=0.8342, Width_avg=0.0667
# a=5.337e-01, dda=8.111e-01, seed=2: SC_robust=0.8354, Width_avg=0.0673
# a=5.337e-01, dda=1.233e+00, seed=1: SC_robust=0.8341, Width_avg=0.0718
# a=5.337e-01, dda=1.233e+00, seed=2: SC_robust=0.8449, Width_avg=0.0716
# a=5.337e-01, dda=1.874e+00, seed=1: SC_robust=0.8467, Width_avg=0.0722
# a=5.337e-01, dda=1.874e+00, seed=2: SC_robust=0.8467, Width_avg=0.0722
# a=5.337e-01, dda=2.848e+00, seed=1: SC_robust=0.8357, Width_avg=0.0689
# a=5.337e-01, dda=2.848e+00, seed=2: SC_robust=0.8469, Width_avg=0.0723
# a=5.337e-01, dda=4.329e+00, seed=1: SC_robust=0.8317, Width_avg=0.0563
# a=5.337e-01, dda=4.329e+00, seed=2: SC_robust=0.8393, Width_avg=0.0698
# a=5.337e-01, dda=6.579e+00, seed=1: SC_robust=0.8458, Width_avg=0.0717
# a=5.337e-01, dda=6.579e+00, seed=2: SC_robust=0.8462, Width_avg=0.0726
# a=5.337e-01, dda=1.000e+01, seed=1: SC_robust=0.7671, Width_avg=0.0574
# a=5.337e-01, dda=1.000e+01, seed=2: SC_robust=0.8332, Width_avg=0.0708
# a=8.111e-01, dda=1.000e-01, seed=1: SC_robust=0.4672, Width_avg=0.0255
# a=8.111e-01, dda=1.000e-01, seed=2: SC_robust=0.4620, Width_avg=0.0251
# a=8.111e-01, dda=1.520e-01, seed=1: SC_robust=0.6302, Width_avg=0.0446
# a=8.111e-01, dda=1.520e-01, seed=2: SC_robust=0.6185, Width_avg=0.0403
# a=8.111e-01, dda=2.310e-01, seed=1: SC_robust=0.6931, Width_avg=0.0433
# a=8.111e-01, dda=2.310e-01, seed=2: SC_robust=0.6838, Width_avg=0.0415
# a=8.111e-01, dda=3.511e-01, seed=1: SC_robust=0.7049, Width_avg=0.0432
# a=8.111e-01, dda=3.511e-01, seed=2: SC_robust=0.7063, Width_avg=0.0444
# a=8.111e-01, dda=5.337e-01, seed=1: SC_robust=0.8794, Width_avg=0.0880
# a=8.111e-01, dda=5.337e-01, seed=2: SC_robust=0.8072, Width_avg=0.0685
# a=8.111e-01, dda=8.111e-01, seed=1: SC_robust=0.9108, Width_avg=0.1017
# a=8.111e-01, dda=8.111e-01, seed=2: SC_robust=0.9096, Width_avg=0.1124
# a=8.111e-01, dda=1.233e+00, seed=1: SC_robust=0.9028, Width_avg=0.1041
# a=8.111e-01, dda=1.233e+00, seed=2: SC_robust=0.7314, Width_avg=0.0502
# a=8.111e-01, dda=1.874e+00, seed=1: SC_robust=0.9266, Width_avg=0.1224
# a=8.111e-01, dda=1.874e+00, seed=2: SC_robust=0.9266, Width_avg=0.1201
# a=8.111e-01, dda=2.848e+00, seed=1: SC_robust=0.9190, Width_avg=0.1201
# a=8.111e-01, dda=2.848e+00, seed=2: SC_robust=0.9216, Width_avg=0.1225
# a=8.111e-01, dda=4.329e+00, seed=1: SC_robust=0.9258, Width_avg=0.1219
# a=8.111e-01, dda=4.329e+00, seed=2: SC_robust=0.9257, Width_avg=0.1272
# a=8.111e-01, dda=6.579e+00, seed=1: SC_robust=0.9266, Width_avg=0.1225
# a=8.111e-01, dda=6.579e+00, seed=2: SC_robust=0.9223, Width_avg=0.1119
# a=8.111e-01, dda=1.000e+01, seed=1: SC_robust=0.9217, Width_avg=0.1100
# a=8.111e-01, dda=1.000e+01, seed=2: SC_robust=0.9281, Width_avg=0.1227
# a=1.233e+00, dda=1.000e-01, seed=1: SC_robust=0.4541, Width_avg=0.0241
# a=1.233e+00, dda=1.000e-01, seed=2: SC_robust=0.4731, Width_avg=0.0286
# a=1.233e+00, dda=1.520e-01, seed=1: SC_robust=0.6181, Width_avg=0.0402
# a=1.233e+00, dda=1.520e-01, seed=2: SC_robust=0.6336, Width_avg=0.0450
# a=1.233e+00, dda=2.310e-01, seed=1: SC_robust=0.6811, Width_avg=0.0433
# a=1.233e+00, dda=2.310e-01, seed=2: SC_robust=0.6948, Width_avg=0.0447
# a=1.233e+00, dda=3.511e-01, seed=1: SC_robust=0.7944, Width_avg=0.0671
# a=1.233e+00, dda=3.511e-01, seed=2: SC_robust=0.7069, Width_avg=0.0432
# a=1.233e+00, dda=5.337e-01, seed=1: SC_robust=0.8529, Width_avg=0.0758
# a=1.233e+00, dda=5.337e-01, seed=2: SC_robust=0.8441, Width_avg=0.0820
# a=1.233e+00, dda=8.111e-01, seed=1: SC_robust=0.6977, Width_avg=0.0466
# a=1.233e+00, dda=8.111e-01, seed=2: SC_robust=0.9145, Width_avg=0.1093
# a=1.233e+00, dda=1.233e+00, seed=1: SC_robust=0.9216, Width_avg=0.1111
# a=1.233e+00, dda=1.233e+00, seed=2: SC_robust=0.9300, Width_avg=0.1130
# a=1.233e+00, dda=1.874e+00, seed=1: SC_robust=0.9284, Width_avg=0.1493
# a=1.233e+00, dda=1.874e+00, seed=2: SC_robust=0.9326, Width_avg=0.1482
# a=1.233e+00, dda=2.848e+00, seed=1: SC_robust=0.9335, Width_avg=0.1278
# a=1.233e+00, dda=2.848e+00, seed=2: SC_robust=0.9332, Width_avg=0.1306
# a=1.233e+00, dda=4.329e+00, seed=1: SC_robust=0.9328, Width_avg=0.1492
# a=1.233e+00, dda=4.329e+00, seed=2: SC_robust=0.8261, Width_avg=0.1330
# a=1.233e+00, dda=6.579e+00, seed=1: SC_robust=0.9039, Width_avg=0.1187
# a=1.233e+00, dda=6.579e+00, seed=2: SC_robust=0.9226, Width_avg=0.1056
# a=1.233e+00, dda=1.000e+01, seed=1: SC_robust=0.9331, Width_avg=0.1459
# a=1.233e+00, dda=1.000e+01, seed=2: SC_robust=0.9240, Width_avg=0.1225
# a=1.874e+00, dda=1.000e-01, seed=1: SC_robust=0.4672, Width_avg=0.0255
# a=1.874e+00, dda=1.000e-01, seed=2: SC_robust=0.4541, Width_avg=0.0241
# a=1.874e+00, dda=1.520e-01, seed=1: SC_robust=0.6305, Width_avg=0.0446
# a=1.874e+00, dda=1.520e-01, seed=2: SC_robust=0.6305, Width_avg=0.0470
# a=1.874e+00, dda=2.310e-01, seed=1: SC_robust=0.6901, Width_avg=0.0415
# a=1.874e+00, dda=2.310e-01, seed=2: SC_robust=0.6298, Width_avg=0.0480
# a=1.874e+00, dda=3.511e-01, seed=1: SC_robust=0.6967, Width_avg=0.0425
# a=1.874e+00, dda=3.511e-01, seed=2: SC_robust=0.6940, Width_avg=0.0456
# a=1.874e+00, dda=5.337e-01, seed=1: SC_robust=0.8454, Width_avg=0.0826
# a=1.874e+00, dda=5.337e-01, seed=2: SC_robust=0.8752, Width_avg=0.1445
# a=1.874e+00, dda=8.111e-01, seed=1: SC_robust=0.8272, Width_avg=0.0708
# a=1.874e+00, dda=8.111e-01, seed=2: SC_robust=0.9169, Width_avg=0.1057
# a=1.874e+00, dda=1.233e+00, seed=1: SC_robust=0.9233, Width_avg=0.1243
# a=1.874e+00, dda=1.233e+00, seed=2: SC_robust=0.8951, Width_avg=0.0970
# a=1.874e+00, dda=1.874e+00, seed=1: SC_robust=0.9245, Width_avg=0.1189
# a=1.874e+00, dda=1.874e+00, seed=2: SC_robust=0.9284, Width_avg=0.1181
# a=1.874e+00, dda=2.848e+00, seed=1: SC_robust=0.9334, Width_avg=0.1501
# a=1.874e+00, dda=2.848e+00, seed=2: SC_robust=0.9122, Width_avg=0.1211
# a=1.874e+00, dda=4.329e+00, seed=1: SC_robust=0.9241, Width_avg=0.0995
# a=1.874e+00, dda=4.329e+00, seed=2: SC_robust=0.9231, Width_avg=0.1398
# a=1.874e+00, dda=6.579e+00, seed=1: SC_robust=0.9221, Width_avg=0.1108
# a=1.874e+00, dda=6.579e+00, seed=2: SC_robust=0.9254, Width_avg=0.1341
# a=1.874e+00, dda=1.000e+01, seed=1: SC_robust=0.9208, Width_avg=0.1218
# a=1.874e+00, dda=1.000e+01, seed=2: SC_robust=0.9158, Width_avg=0.1221
# a=2.848e+00, dda=1.000e-01, seed=1: SC_robust=0.4672, Width_avg=0.0253
# a=2.848e+00, dda=1.000e-01, seed=2: SC_robust=0.4541, Width_avg=0.0255
# a=2.848e+00, dda=1.520e-01, seed=1: SC_robust=0.6266, Width_avg=0.0443
# a=2.848e+00, dda=1.520e-01, seed=2: SC_robust=0.6181, Width_avg=0.0403
# a=2.848e+00, dda=2.310e-01, seed=1: SC_robust=0.6951, Width_avg=0.0440
# a=2.848e+00, dda=2.310e-01, seed=2: SC_robust=0.6947, Width_avg=0.0463
# a=2.848e+00, dda=3.511e-01, seed=1: SC_robust=0.6411, Width_avg=0.0424
# a=2.848e+00, dda=3.511e-01, seed=2: SC_robust=0.7736, Width_avg=0.0671
# a=2.848e+00, dda=5.337e-01, seed=1: SC_robust=0.8426, Width_avg=0.0810
# a=2.848e+00, dda=5.337e-01, seed=2: SC_robust=0.8378, Width_avg=0.0692
# a=2.848e+00, dda=8.111e-01, seed=1: SC_robust=0.9227, Width_avg=0.1140
# a=2.848e+00, dda=8.111e-01, seed=2: SC_robust=0.9133, Width_avg=0.1322
# a=2.848e+00, dda=1.233e+00, seed=1: SC_robust=0.9296, Width_avg=0.1403
# a=2.848e+00, dda=1.233e+00, seed=2: SC_robust=0.8074, Width_avg=0.0789
# a=2.848e+00, dda=1.874e+00, seed=1: SC_robust=0.8146, Width_avg=0.0834
# a=2.848e+00, dda=1.874e+00, seed=2: SC_robust=0.9334, Width_avg=0.1240
# a=2.848e+00, dda=2.848e+00, seed=1: SC_robust=0.9246, Width_avg=0.1133
# a=2.848e+00, dda=2.848e+00, seed=2: SC_robust=0.9334, Width_avg=0.1236
# a=2.848e+00, dda=4.329e+00, seed=1: SC_robust=0.8968, Width_avg=0.1025
# a=2.848e+00, dda=4.329e+00, seed=2: SC_robust=0.9255, Width_avg=0.1611
# a=2.848e+00, dda=6.579e+00, seed=1: SC_robust=0.9130, Width_avg=0.1061
# a=2.848e+00, dda=6.579e+00, seed=2: SC_robust=0.9244, Width_avg=0.1269
# a=2.848e+00, dda=1.000e+01, seed=1: SC_robust=0.9342, Width_avg=0.1352
# a=2.848e+00, dda=1.000e+01, seed=2: SC_robust=0.9261, Width_avg=0.1115
# a=4.329e+00, dda=1.000e-01, seed=1: SC_robust=0.4672, Width_avg=0.0255
# a=4.329e+00, dda=1.000e-01, seed=2: SC_robust=0.4672, Width_avg=0.0253
# a=4.329e+00, dda=1.520e-01, seed=1: SC_robust=0.6178, Width_avg=0.0408
# a=4.329e+00, dda=1.520e-01, seed=2: SC_robust=0.6181, Width_avg=0.0401
# a=4.329e+00, dda=2.310e-01, seed=1: SC_robust=0.6926, Width_avg=0.0432
# a=4.329e+00, dda=2.310e-01, seed=2: SC_robust=0.6910, Width_avg=0.0430
# a=4.329e+00, dda=3.511e-01, seed=1: SC_robust=0.7045, Width_avg=0.0441
# a=4.329e+00, dda=3.511e-01, seed=2: SC_robust=0.7962, Width_avg=0.0678
# a=4.329e+00, dda=5.337e-01, seed=1: SC_robust=0.8824, Width_avg=0.1226
# a=4.329e+00, dda=5.337e-01, seed=2: SC_robust=0.7449, Width_avg=0.0570
# a=4.329e+00, dda=8.111e-01, seed=1: SC_robust=0.9082, Width_avg=0.1339
# a=4.329e+00, dda=8.111e-01, seed=2: SC_robust=0.9206, Width_avg=0.1793
# a=4.329e+00, dda=1.233e+00, seed=1: SC_robust=0.9210, Width_avg=0.1213
# a=4.329e+00, dda=1.233e+00, seed=2: SC_robust=0.9162, Width_avg=0.1009
# a=4.329e+00, dda=1.874e+00, seed=1: SC_robust=0.9241, Width_avg=0.1034
# a=4.329e+00, dda=1.874e+00, seed=2: SC_robust=0.9246, Width_avg=0.1057
# a=4.329e+00, dda=2.848e+00, seed=1: SC_robust=0.9255, Width_avg=0.1319
# a=4.329e+00, dda=2.848e+00, seed=2: SC_robust=0.9323, Width_avg=0.1623
# a=4.329e+00, dda=4.329e+00, seed=1: SC_robust=0.9253, Width_avg=0.0987
# a=4.329e+00, dda=4.329e+00, seed=2: SC_robust=0.9302, Width_avg=0.1826
# a=4.329e+00, dda=6.579e+00, seed=1: SC_robust=0.6810, Width_avg=0.0726
# a=4.329e+00, dda=6.579e+00, seed=2: SC_robust=0.9253, Width_avg=0.1239
# a=4.329e+00, dda=1.000e+01, seed=1: SC_robust=0.9249, Width_avg=0.0984
# a=4.329e+00, dda=1.000e+01, seed=2: SC_robust=0.9151, Width_avg=0.0982
# a=6.579e+00, dda=1.000e-01, seed=1: SC_robust=0.4672, Width_avg=0.0255
# a=6.579e+00, dda=1.000e-01, seed=2: SC_robust=0.4541, Width_avg=0.0257
# a=6.579e+00, dda=1.520e-01, seed=1: SC_robust=0.6302, Width_avg=0.0471
# a=6.579e+00, dda=1.520e-01, seed=2: SC_robust=0.5794, Width_avg=0.0574
# a=6.579e+00, dda=2.310e-01, seed=1: SC_robust=0.6738, Width_avg=0.0422
# a=6.579e+00, dda=2.310e-01, seed=2: SC_robust=0.6909, Width_avg=0.0427
# a=6.579e+00, dda=3.511e-01, seed=1: SC_robust=0.7973, Width_avg=0.0580
# a=6.579e+00, dda=3.511e-01, seed=2: SC_robust=0.7968, Width_avg=0.0618
# a=6.579e+00, dda=5.337e-01, seed=1: SC_robust=0.8232, Width_avg=0.0887
# a=6.579e+00, dda=5.337e-01, seed=2: SC_robust=0.8822, Width_avg=0.1341
# a=6.579e+00, dda=8.111e-01, seed=1: SC_robust=0.9094, Width_avg=0.1000
# a=6.579e+00, dda=8.111e-01, seed=2: SC_robust=0.9066, Width_avg=0.0678
# a=6.579e+00, dda=1.233e+00, seed=1: SC_robust=0.9226, Width_avg=0.0990
# a=6.579e+00, dda=1.233e+00, seed=2: SC_robust=0.8404, Width_avg=0.0829
# a=6.579e+00, dda=1.874e+00, seed=1: SC_robust=0.9202, Width_avg=0.0986
# a=6.579e+00, dda=1.874e+00, seed=2: SC_robust=0.7225, Width_avg=0.0363
# a=6.579e+00, dda=2.848e+00, seed=1: SC_robust=0.9247, Width_avg=0.1059
# a=6.579e+00, dda=2.848e+00, seed=2: SC_robust=0.9238, Width_avg=0.1071
# a=6.579e+00, dda=4.329e+00, seed=1: SC_robust=0.8983, Width_avg=0.1170
# a=6.579e+00, dda=4.329e+00, seed=2: SC_robust=0.9252, Width_avg=0.1090
# a=6.579e+00, dda=6.579e+00, seed=1: SC_robust=0.9254, Width_avg=0.1135
# a=6.579e+00, dda=6.579e+00, seed=2: SC_robust=0.9164, Width_avg=0.1092
# a=6.579e+00, dda=1.000e+01, seed=1: SC_robust=0.9014, Width_avg=0.1115
# a=6.579e+00, dda=1.000e+01, seed=2: SC_robust=0.8991, Width_avg=0.1290
# a=1.000e+01, dda=1.000e-01, seed=1: SC_robust=0.4672, Width_avg=0.0255
# a=1.000e+01, dda=1.000e-01, seed=2: SC_robust=0.4672, Width_avg=0.0276
# a=1.000e+01, dda=1.520e-01, seed=1: SC_robust=0.6178, Width_avg=0.0389
# a=1.000e+01, dda=1.520e-01, seed=2: SC_robust=0.6295, Width_avg=0.0442
# a=1.000e+01, dda=2.310e-01, seed=1: SC_robust=0.6910, Width_avg=0.0438
# a=1.000e+01, dda=2.310e-01, seed=2: SC_robust=0.6904, Width_avg=0.0428
# a=1.000e+01, dda=3.511e-01, seed=1: SC_robust=0.6895, Width_avg=0.0464
# a=1.000e+01, dda=3.511e-01, seed=2: SC_robust=0.7959, Width_avg=0.0740
# a=1.000e+01, dda=5.337e-01, seed=1: SC_robust=0.5527, Width_avg=0.0476
# a=1.000e+01, dda=5.337e-01, seed=2: SC_robust=0.8312, Width_avg=0.0920
# a=1.000e+01, dda=8.111e-01, seed=1: SC_robust=0.8828, Width_avg=0.0951
# a=1.000e+01, dda=8.111e-01, seed=2: SC_robust=0.9130, Width_avg=0.1425
# a=1.000e+01, dda=1.233e+00, seed=1: SC_robust=0.9209, Width_avg=0.1071
# a=1.000e+01, dda=1.233e+00, seed=2: SC_robust=0.9231, Width_avg=0.1518
# a=1.000e+01, dda=1.874e+00, seed=1: SC_robust=0.8945, Width_avg=0.1165
# a=1.000e+01, dda=1.874e+00, seed=2: SC_robust=0.9096, Width_avg=0.1048
# a=1.000e+01, dda=2.848e+00, seed=1: SC_robust=0.8737, Width_avg=0.1289
# a=1.000e+01, dda=2.848e+00, seed=2: SC_robust=0.9222, Width_avg=0.1076
# a=1.000e+01, dda=4.329e+00, seed=1: SC_robust=0.7123, Width_avg=0.1003
# a=1.000e+01, dda=4.329e+00, seed=2: SC_robust=0.9307, Width_avg=0.1206
# a=1.000e+01, dda=6.579e+00, seed=1: SC_robust=0.8584, Width_avg=0.1213
# a=1.000e+01, dda=6.579e+00, seed=2: SC_robust=0.9336, Width_avg=0.1245
# a=1.000e+01, dda=1.000e+01, seed=1: SC_robust=0.7502, Width_avg=0.0357
# a=1.000e+01, dda=1.000e+01, seed=2: SC_robust=0.8704, Width_avg=0.1238
#
# Multi-seed robustness analysis complete (Universal)!
